# %%
# !pip install beautifulsoup4
# !conda install beautifulsoup4
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
import re

# %%
#url = "https://stats.oecd.org/Index.aspx?DataSetCode=RMW"
url = 'https://en.wikipedia.org/wiki/List_of_countries_by_minimum_wage'

# %%
wage_response = requests.get(url)
print(wage_response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(wage_response.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of countries by minimum wage - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"03ad16a5-a413-425e-ba8d-c1c0490559e3","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_minimum_wage","wgTitle":"List of countries by minimum wage","wgCurRevisionId":1058933720,"wgRevisionId":1058933720,"wgArticleId":4470657,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","CS1 French-language sources (fr)","CS1 Azerbaijani-language sources (az)","CS1 Spanish-language sources (es)","CS1 Portuguese-language sources (pt)","CS1 Bulgarian-language sources (bg)",
# "CS1 maint: archived copy as title","CS1 Chinese-language sources (zh)","CS1 Croatian-language sources (hr)","CS1 Estonian-language sources (et)","CS1 uses Japanese-language script (ja)","CS1 Japanese-language sources (ja)","CS1 Latvian-language sources (lv)","CS1 Mongolian-language sources (mn)","CS1 errors: missing title","CS1 errors: bare URL","CS1 maint: bot: original URL status unknown","CS1 German-language sources (de)","CS1 Italian-language sources (it)","Articles with short description","Short description is different from Wikidata","Articles with obsolete information from October 2020","All Wikipedia articles in need of updating","All accuracy disputes","Articles with disputed statements from August 2018","Articles containing potentially dated statements from July 2019","All articles containing potentially dated statements","Minimum wage","Lists of countries by economic indicator","Law-related lists"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext",
# "wgRelevantPageName":"List_of_countries_by_minimum_wage","wgRelevantArticleId":4470657,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":100000,"wgNoticeProject":"wikipedia","wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q1153034","wgGENewcomerTasksGuidanceEnabled":true,"wgGEAskQuestionEnabled":false,"wgGELinkRecommendationsFrontendEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready",
# "site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp",
# "ext.centralauth.centralautologin","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.38.0-wmf.9" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Minimum_wages_by_territory.png/1200px-Minimum_wages_by_territory.png" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="605" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Minimum_wages_by_territory.png/800px-Minimum_wages_by_territory.png" property="og:image"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="403" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Minimum_wages_by_territory.png/640px-Minimum_wages_by_territory.png" property="og:image"/>
#   <meta content="640" property="og:image:width"/>
#   <meta content="322" property="og:image:height"/>
#   <meta content="List of countries by minimum wage - Wikipedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/List_of_countries_by_minimum_wage" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_countries_by_minimum_wage&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_countries_by_minimum_wage" rel="canonical"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_countries_by_minimum_wage rootpage-List_of_countries_by_minimum_wage skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#    </div>
#    <h1 class="firstHeading" id="firstHeading">
#     List of countries by minimum wage
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Wikipedia list article
#       </div>
#       <table class="box-Update plainlinks metadata ambox ambox-content ambox-Update" role="presentation">
#        <tbody>
#         <tr>
#          <td class="mbox-image">
#           <div style="width:52px">
#            <img alt="Ambox current red Americas.svg" data-file-height="290" data-file-width="360" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/42px-Ambox_current_red_Americas.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/63px-Ambox_current_red_Americas.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/84px-Ambox_current_red_Americas.svg.png 2x" width="42"/>
#           </div>
#          </td>
#          <td class="mbox-text">
#           <div class="mbox-text-span">
#            This article's
#            <b>
#             <a href="/wiki/Wikipedia:Accuracy_dispute" title="Wikipedia:Accuracy dispute">
#              factual accuracy
#             </a>
#             may be compromised due to out-of-date information
#            </b>
#            . The reason given is: policy changes and inflation are not adequately reflected; inconsistent use of current and outdated minimum wages limits the ability to accurately compare countries.
#            <span class="hide-when-compact">
#             Please help update this  to reflect recent events or newly available information.
#            </span>
#            <span class="date-container">
#             <i>
#              (
#              <span class="date">
#               October 2020
#              </span>
#              )
#             </i>
#            </span>
#           </div>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:222px;">
#         <a class="image" href="/wiki/File:Minimum_wages_by_territory.png">
#          <img alt="" class="thumbimage" data-file-height="3542" data-file-width="7030" decoding="async" height="111" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Minimum_wages_by_territory.png/220px-Minimum_wages_by_territory.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Minimum_wages_by_territory.png/330px-Minimum_wages_by_territory.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Minimum_wages_by_territory.png/440px-Minimum_wages_by_territory.png 2x" width="220"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Minimum_wages_by_territory.png" title="Enlarge">
#           </a>
#          </div>
#          Global minimum wages by territory
#         </div>
#        </div>
#       </div>
#       <p>
#        This is a list of the official
#        <a href="/wiki/Minimum_wage" title="Minimum wage">
#         minimum wage
#        </a>
#        rates of the 193
#        <a class="mw-redirect" href="/wiki/United_Nations_member_states" title="United Nations member states">
#         United Nations member states
#        </a>
#        and former members of the
#        <a href="/wiki/United_Nations" title="United Nations">
#         United Nations
#        </a>
#        , also including the following territories and states with limited recognition:
#        <a href="/wiki/Northern_Cyprus" title="Northern Cyprus">
#         Northern Cyprus
#        </a>
#        , and
#        <a href="/wiki/Kosovo" title="Kosovo">
#         Kosovo
#        </a>
#        and other independent countries. Some countries may have a very complicated minimum wage system; for example, India has more than 1202 minimum wage rates for different types of industries and skill levels.
#        <sup class="reference" id="cite_ref-1">
#         <a href="#cite_note-1">
#          [1]
#         </a>
#        </sup>
#        Meanwhile other countries may have a national rate which often is superseded by state, provincial, cantonal, county and city minimum wage rates. For example 33 states in the
#        <a href="/wiki/United_States" title="United States">
#         United States
#        </a>
#        have higher minimum wages than the Federal rate (plus military rates on federal bases) - on top of this an additional 42 city-level subdivisions having different minimum wage rates and 53 counties.
#        <sup class="reference" id="cite_ref-2">
#         <a href="#cite_note-2">
#          [2]
#         </a>
#        </sup>
#        In effect the United States has over 100 different minimum wages across the nation. This is common in Federal nations as
#        <a href="/wiki/Canada" title="Canada">
#         Canada
#        </a>
#        <sup class="reference" id="cite_ref-3">
#         <a href="#cite_note-3">
#          [3]
#         </a>
#        </sup>
#        and
#        <a href="/wiki/Minimum_wage_in_China" title="Minimum wage in China">
#         China
#        </a>
#        also have numerous different rates. In the article below only the lowest minimum wage is cited, or the highest-level subdivision where it applies.
#       </p>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2 id="mw-toc-heading">
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Methodology">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Methodology
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-2">
#          <a href="#List">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            List
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-3">
#          <a href="#OECD">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            OECD
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-4">
#          <a href="#See_also">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            See also
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-5">
#          <a href="#Notes">
#           <span class="tocnumber">
#            5
#           </span>
#           <span class="toctext">
#            Notes
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-6">
#          <a href="#References">
#           <span class="tocnumber">
#            6
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-7">
#          <a href="#External_links">
#           <span class="tocnumber">
#            7
#           </span>
#           <span class="toctext">
#            External links
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="Methodology">
#         Methodology
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_countries_by_minimum_wage&amp;action=edit&amp;section=1" title="Edit section: Methodology">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        The minimum wages listed refer to a
#        <a href="/wiki/Gross_income" title="Gross income">
#         gross
#        </a>
#        amount, that is before
#        <a href="/wiki/Tax_deduction" title="Tax deduction">
#         deduction of taxes
#        </a>
#        and
#        <a class="mw-redirect" href="/wiki/Social_security" title="Social security">
#         social security
#        </a>
#        contributions, which vary from one country to another. Also excluded from calculations are regulated paid days off, including public holidays, sick pay, annual leave and
#        <a href="/wiki/Social_insurance" title="Social insurance">
#         social insurance
#        </a>
#        contributions paid by the employer.
#       </p>
#       <p>
#        For the sake of comparison, an annual wage column is provided in
#        <a class="mw-redirect" href="/wiki/Geary%E2%80%93Khamis_dollar" title="Geary–Khamis dollar">
#         international dollars
#        </a>
#        , a hypothetical unit of
#        <a href="/wiki/Currency" title="Currency">
#         currency
#        </a>
#        calculated based on the
#        <a href="/wiki/Purchasing_power_parity" title="Purchasing power parity">
#         purchasing power parity
#        </a>
#        (PPP) of
#        <a href="/wiki/Household_final_consumption_expenditure" title="Household final consumption expenditure">
#         household final consumption expenditure
#        </a>
#        . For calculating the annual wage, the lowest general minimum wage was used.
#       </p>
#       <h2>
#        <span class="mw-headline" id="List">
#         List
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_countries_by_minimum_wage&amp;action=edit&amp;section=2" title="Edit section: List">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <p>
#        <style data-mw-deduplicate="TemplateStyles:r1049062077">
#         .mw-parser-output table.static-row-numbers{counter-reset:rowNumber}body.skin-minerva .mw-parser-output .static-row-numbers2.sortable{counter-reset:rowNumber -1}body.skin-minerva .mw-parser-output .static-row-numbers2.sortable.static-row-header-two{counter-reset:rowNumber -2}.mw-parser-output table.static-row-numbers tr::before{display:table-cell;padding:0 0.5em;text-align:right}.mw-parser-output table.static-row-numbers tr::before{content:""}body:not(.skin-minerva) .mw-parser-output .static-row-numbers.sortable tbody tr:not(.static-row-header):not(.static-row-numbers-norank)::before,body.skin-minerva .mw-parser-output .static-row-numbers tbody tr:not(:first-child):not(.static-row-header):not(.static-row-numbers-norank)::before,.mw-parser-output table.static-row-numbers:not(.sortable) tbody tr:not(:first-child):not(.static-row-header):not(.static-row-numbers-norank)::before{counter-increment:rowNumber;content:counter(rowNumber);vertical-align:inherit}.mw-parser-output .static-row-header-hash thead tr::before{content:"#"}.mw-parser-output .static-row-header-row thead tr::before{content:"Row"}.mw-parser-output .static-row-numbers.wikitable tr::before{background-color:#eaecf0}body:not(.skin-minerva) .mw-parser-output .static-row-numbers.mw-datatable:not(.wikitable) tr::before{background-color:#eaeeff}.mw-parser-output table.static-row-numbers.wikitable tbody tr:not(.static-row-header)::before,body:not(.skin-minerva) .mw-parser-output .static-row-numbers.mw-datatable:not(.wikitable) tbody tr::before{border:1px solid #a2a9b1}.mw-parser-output .static-row-numbers-period2 tbody tr::before{content:counter(rowNumber)"."}.mw-parser-output .srn-white-background{background:#fff}.mw-parser-output .static-row-numbers tr:hover{background:#eaf3ff}
#        </style>
#        .
#       </p>
#       <table border="1" class="wikitable sortable static-row-numbers plainrowheaders srn-white-background" style="text-align:right;">
#        <tbody>
#         <tr>
#          <th rowspan="2">
#           Country
#          </th>
#          <th class="unsortable" rowspan="2">
#           Minimum wage
#          </th>
#          <th colspan="2">
#           Annual
#          </th>
#          <th rowspan="2">
#           Workweek
#           <br/>
#           (hours)
#           <sup class="reference" id="cite_ref-4">
#            <a href="#cite_note-4">
#             [4]
#            </a>
#           </sup>
#          </th>
#          <th colspan="2">
#           Hourly
#          </th>
#          <th rowspan="2">
#           Percent of
#           <br/>
#           GDP per capita
#           <sup class="reference" id="cite_ref-5">
#            <a href="#cite_note-5">
#             [5]
#            </a>
#           </sup>
#          </th>
#          <th rowspan="2">
#           Effective per
#          </th>
#         </tr>
#         <tr>
#          <th>
#           Nominal (US$)
#           <sup class="reference" id="cite_ref-6">
#            <a href="#cite_note-6">
#             [6]
#            </a>
#           </sup>
#          </th>
#          <th>
#           PPP (
#           <a class="mw-redirect" href="/wiki/Geary-Khamis_dollar" title="Geary-Khamis dollar">
#            Int$
#           </a>
#           )
#           <sup class="reference" id="cite_ref-7">
#            <a href="#cite_note-7">
#             [7]
#            </a>
#           </sup>
#          </th>
#          <th>
#           Nominal (US$)
#           <sup class="reference" id="cite_ref-8">
#            <a href="#cite_note-8">
#             [8]
#            </a>
#           </sup>
#          </th>
#          <th>
#           PPP (
#           <a class="mw-redirect" href="/wiki/Geary-Khamis_dollar" title="Geary-Khamis dollar">
#            Int$
#           </a>
#           )
#           <sup class="reference" id="cite_ref-9">
#            <a href="#cite_note-9">
#             [9]
#            </a>
#           </sup>
#           <p>
#            <br/>
#           </p>
#          </th>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="500" data-file-width="1000" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/23px-Flag_of_the_Taliban.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/35px-Flag_of_the_Taliban.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_the_Taliban.svg/46px-Flag_of_the_Taliban.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Afghanistan" title="Afghanistan">
#            Afghanistan
#           </a>
#          </td>
#          <td>
#           5,500
#           <a href="/wiki/Afghan_afghani" title="Afghan afghani">
#            Afghani
#           </a>
#           ($67) per month for non-permanent private sector. The minimum wage for permanent government workers was 6,000 Afghanis ($74) per month. There was no minimum wage for permanent workers in the private sector.
#           <sup class="reference" id="cite_ref-CRHRP-2012_10-0">
#            <a href="#cite_note-CRHRP-2012-10">
#             [10]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7002866000000000000♠">
#            866
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003327200000000000♠">
#             3,272
#            </span>
#           </p>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="6999420000000000000♠">
#            0.42
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7000157000000000000♠">
#             1.57
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7002168300000000000♠">
#            168.3
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002017-01-01-0000" style="white-space:nowrap">
#            2017
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="700" data-file-width="980" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/21px-Flag_of_Albania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/32px-Flag_of_Albania.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/42px-Flag_of_Albania.svg.png 2x" width="21"/>
#           </span>
#           <a href="/wiki/Albania" title="Albania">
#            Albania
#           </a>
#          </td>
#          <td>
#           30,000
#           <a href="/wiki/Albanian_lek" title="Albanian lek">
#            Albanian lek
#           </a>
#           ë ($280) per month, in private sector and 37,000 lekë ($332) per month in public sector. The law establishes a 40-hour workweek, but the actual workweek is typically set by individual or collective-bargaining agreement.
#           <sup class="reference" id="cite_ref-CRHRP-2012_10-1">
#            <a href="#cite_note-CRHRP-2012-10">
#             [10]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-11">
#            <a href="#cite_note-11">
#             [11]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-12">
#            <a href="#cite_note-12">
#             [12]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-albania_13-0">
#            <a href="#cite_note-albania-13">
#             [13]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7003327700000000000♠">
#            3,277
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003652300000000000♠">
#             6,523
#            </span>
#           </p>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="7000158000000000000♠">
#            1.58
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7000314000000000000♠">
#             3.14
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001565000000000000♠">
#            56.5
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002017-05-05-0000" style="white-space:nowrap">
#            5 May 2017
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/23px-Flag_of_Algeria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/35px-Flag_of_Algeria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_Algeria.svg/45px-Flag_of_Algeria.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Algeria" title="Algeria">
#            Algeria
#           </a>
#          </td>
#          <td>
#           20,000
#           <a href="/wiki/Algerian_dinar" title="Algerian dinar">
#            Algerian dinars
#           </a>
#           ($156.19) per month, nationally.
#           <sup class="reference" id="cite_ref-14">
#            <a href="#cite_note-14">
#             [14]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-15">
#            <a href="#cite_note-15">
#             [15]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7003201000000000000♠">
#            2,010
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003624700000000000♠">
#             6,247
#            </span>
#           </p>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="6999970000000000000♠">
#            0.97
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7000300000000000000♠">
#             3
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001416000000000000♠">
#            41.6
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002020-05-01-0000" style="white-space:nowrap">
#            1 May 2020
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="700" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/22px-Flag_of_Andorra.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/33px-Flag_of_Andorra.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/43px-Flag_of_Andorra.svg.png 2x" width="22"/>
#           </span>
#           <a href="/wiki/Andorra" title="Andorra">
#            Andorra
#           </a>
#          </td>
#          <td>
#           €1050.40 per month, €6.06 per hour.
#           <sup class="reference" id="cite_ref-16">
#            <a href="#cite_note-16">
#             [16]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7004143970000000000♠">
#            14,397
#           </span>
#          </td>
#          <td>
#           <span data-sort-value="7004110200000000000♠">
#            11,020
#           </span>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="7000672000000000000♠">
#            6.72
#           </span>
#          </td>
#          <td>
#           <span data-sort-value="7000530000000000000♠">
#            5.3
#           </span>
#          </td>
#          <td>
#           <span data-sort-value="7001280000000000000♠">
#            28
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002019-01-01-0000" style="white-space:nowrap">
#            1 January 2019
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Angola.svg/23px-Flag_of_Angola.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Angola.svg/35px-Flag_of_Angola.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Angola.svg/45px-Flag_of_Angola.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Angola" title="Angola">
#            Angola
#           </a>
#          </td>
#          <td>
#           21,454
#           <a href="/wiki/Angolan_kwanza" title="Angolan kwanza">
#            kwanza
#           </a>
#           ($58) per month; paid thirteen times a year.
#           <sup class="reference" id="cite_ref-17">
#            <a href="#cite_note-17">
#             [17]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-wageindicator_18-0">
#            <a href="#cite_note-wageindicator-18">
#             [18]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7002764000000000000♠">
#            764
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003210800000000000♠">
#             2,108
#            </span>
#           </p>
#          </td>
#          <td>
#           44
#          </td>
#          <td>
#           <span data-sort-value="6999330000000000000♠">
#            0.33
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="6999920000000000000♠">
#             0.92
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001327000000000000♠">
#            32.7
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002019-04-01-0000" style="white-space:nowrap">
#            1 April 2019
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/23px-Flag_of_Antigua_and_Barbuda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/35px-Flag_of_Antigua_and_Barbuda.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/45px-Flag_of_Antigua_and_Barbuda.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Antigua_and_Barbuda" title="Antigua and Barbuda">
#            Antigua and Barbuda
#           </a>
#          </td>
#          <td>
#           <a class="mw-redirect" href="/wiki/East_Caribbean_dollar" title="East Caribbean dollar">
#            EC$
#           </a>
#           8.20 per hour (US$3.03).
#           <sup class="reference" id="cite_ref-CRHRP-2012_10-2">
#            <a href="#cite_note-CRHRP-2012-10">
#             [10]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-19">
#            <a href="#cite_note-19">
#             [19]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-20">
#            <a href="#cite_note-20">
#             [20]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7003631700000000000♠">
#            6,317
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003778800000000000♠">
#             7,788
#            </span>
#           </p>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="7000304000000000000♠">
#            3.04
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7000374000000000000♠">
#             3.74
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001344000000000000♠">
#            34.4
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002014-11-01-0000" style="white-space:nowrap">
#            1 November 2014
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/23px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/35px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/46px-Flag_of_Argentina.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Argentina" title="Argentina">
#            Argentina
#           </a>
#          </td>
#          <td>
#           32,000
#           <a href="/wiki/Argentine_peso" title="Argentine peso">
#            Argentine pesos
#           </a>
#           ($305) per month for up to 200 hours; paid thirteen times a year.
#           <sup class="reference" id="cite_ref-21">
#            <a href="#cite_note-21">
#             [21]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-22">
#            <a href="#cite_note-22">
#             [22]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7003864000000000000♠">
#            8,640
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7004446450000000000♠">
#             44,645
#            </span>
#           </p>
#          </td>
#          <td>
#           48
#          </td>
#          <td>
#           <span data-sort-value="7000346000000000000♠">
#            3.46
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7001178900000000000♠">
#             17.89
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7002223900000000000♠">
#            223.9
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002021-11-01-0000" style="white-space:nowrap">
#            1 November 2021
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/23px-Flag_of_Armenia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/35px-Flag_of_Armenia.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/46px-Flag_of_Armenia.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Armenia" title="Armenia">
#            Armenia
#           </a>
#          </td>
#          <td>
#           68,000
#           <a href="/wiki/Armenian_dram" title="Armenian dram">
#            Armenian dram
#           </a>
#           ($143) per month.
#           <sup class="reference" id="cite_ref-CRHRP-2012_10-3">
#            <a href="#cite_note-CRHRP-2012-10">
#             [10]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-23">
#            <a href="#cite_note-23">
#             [23]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7003169800000000000♠">
#            1,698
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003414000000000000♠">
#             4,140
#            </span>
#           </p>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="6999820000000000000♠">
#            0.82
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7000199000000000000♠">
#             1.99
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001469000000000000♠">
#            46.9
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002019-07-01-0000" style="white-space:nowrap">
#            1 July 2019
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="640" data-file-width="1280" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/23px-Flag_of_Australia_%28converted%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/35px-Flag_of_Australia_%28converted%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/46px-Flag_of_Australia_%28converted%29.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Australia" title="Australia">
#            Australia
#           </a>
#          </td>
#          <td>
#           Most workers are covered by an
#           <a href="/wiki/Industrial_award" title="Industrial award">
#            award
#           </a>
#           , which may vary by employee age, geographical location and industry. Workers receive mandatory employer
#           <a href="/wiki/Superannuation_in_Australia" title="Superannuation in Australia">
#            superannuation contributions
#           </a>
#           of at least 10% (increasing to 12% by 2025) of wages, alongside loadings such as penalty rates or leave loading. Minimum wages are set federally by the
#           <a href="/wiki/Fair_Work_Commission" title="Fair Work Commission">
#            Fair Work Commission
#           </a>
#           .
#           <br/>
#           <br/>
#           <p>
#            For those 21 and older, not covered by an award or other instrument, the minimum wages is
#            <a class="mw-redirect" href="/wiki/Australian_Dollar" title="Australian Dollar">
#             A$
#            </a>
#            772.60 ($568.34 USD) per week, or
#            <a class="mw-redirect" href="/wiki/Australian_Dollar" title="Australian Dollar">
#             A$
#            </a>
#            20.33 ($14.95 USD) per hour.
#            <sup class="reference" id="cite_ref-Fair_Work_Ombudsman_24-0">
#             <a href="#cite_note-Fair_Work_Ombudsman-24">
#              [24]
#             </a>
#            </sup>
#            <a href="/wiki/Casual_employment_(contract)#Australia" title="Casual employment (contract)">
#             Casual workers
#            </a>
#            are paid a loading of typically 25%, resulting in a minimum of
#            <a class="mw-redirect" href="/wiki/Australian_Dollar" title="Australian Dollar">
#             A$
#            </a>
#            24.80 per hour for those workers.
#            <br/>
#            <br/>
#            Workers under 21, apprentices and trainees not covered by an award, have a minimum wages set at a percentage of the ordinary rate.
#            <sup class="reference" id="cite_ref-Fair_Work_Ombudsman_24-1">
#             <a href="#cite_note-Fair_Work_Ombudsman-24">
#              [24]
#             </a>
#            </sup>
#            For those under 16, this is 36.8% or
#            <a class="mw-redirect" href="/wiki/Australian_Dollar" title="Australian Dollar">
#             A$
#            </a>
#            7.30 per hour;
#            <a class="mw-redirect" href="/wiki/Australian_Dollar" title="Australian Dollar">
#             A$
#            </a>
#            9.13 with the casual loading.
#            <sup class="reference" id="cite_ref-25">
#             <a href="#cite_note-25">
#              [25]
#             </a>
#            </sup>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7004287340000000000♠">
#            28,734
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7004251100000000000♠">
#             25,110
#            </span>
#           </p>
#          </td>
#          <td>
#           38
#          </td>
#          <td>
#           <span data-sort-value="7001145400000000000♠">
#            14.54
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7001127100000000000♠">
#             12.71
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001546000000000000♠">
#            54.6
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002021-07-01-0000" style="white-space:nowrap">
#            1 July 2021
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/23px-Flag_of_Austria.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/35px-Flag_of_Austria.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/41/Flag_of_Austria.svg/45px-Flag_of_Austria.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Austria" title="Austria">
#            Austria
#           </a>
#          </td>
#          <td>
#           None; National collective bargaining agreements set minimum wages by job classification for each industry and provide for a minimum wage of
#           <a href="/wiki/Euro" title="Euro">
#            €
#           </a>
#           1,200 ($1,289) per month
#           <sup class="noprint Inline-Template" style="white-space:nowrap;">
#            [
#            <i>
#             <a href="/wiki/Wikipedia:Accuracy_dispute#Disputed_statement" title="Wikipedia:Accuracy dispute">
#              <span title="The material near this tag is possibly inaccurate or nonfactual. (August 2018)">
#               dubious
#              </span>
#             </a>
#             <span class="metadata">
#              –
#              <a href="/wiki/Talk:List_of_countries_by_minimum_wage#Dubious" title="Talk:List of countries by minimum wage">
#               discuss
#              </a>
#             </span>
#            </i>
#            ]
#           </sup>
#           . Wages where no such collective agreements exist, such as for domestic workers, janitorial staff and au pairs, are regulated by relevant legislation and are generally lower than those covered by collective bargaining. The national minimum wage legislation has lapsed, although is still in force by convention.
#           <sup class="reference" id="cite_ref-26">
#            <a href="#cite_note-26">
#             [26]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-CRHRP-2012_10-4">
#            <a href="#cite_note-CRHRP-2012-10">
#             [10]
#            </a>
#           </sup>
#          </td>
#          <td>
#          </td>
#          <td>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#          </td>
#          <td>
#          </td>
#          <td>
#          </td>
#          <td>
#           <span data-sort-value="000000002017-01-01-0000" style="white-space:nowrap">
#            2017
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Flag_of_Azerbaijan.svg/23px-Flag_of_Azerbaijan.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Flag_of_Azerbaijan.svg/35px-Flag_of_Azerbaijan.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Flag_of_Azerbaijan.svg/46px-Flag_of_Azerbaijan.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Azerbaijan" title="Azerbaijan">
#            Azerbaijan
#           </a>
#          </td>
#          <td>
#           250
#           <a href="/wiki/Azerbaijani_manat" title="Azerbaijani manat">
#            Azerbaijani manat
#           </a>
#           (146$) per month.
#           <sup class="reference" id="cite_ref-27">
#            <a href="#cite_note-27">
#             [27]
#            </a>
#           </sup>
#           <sup class="reference" id="cite_ref-28">
#            <a href="#cite_note-28">
#             [28]
#            </a>
#           </sup>
#          </td>
#          <td>
#           <span data-sort-value="7003176500000000000♠">
#            1,765
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7003857100000000000♠">
#             8,571
#            </span>
#           </p>
#          </td>
#          <td>
#           40
#          </td>
#          <td>
#           <span data-sort-value="6999850000000000000♠">
#            0.85
#           </span>
#          </td>
#          <td>
#           <p>
#            <span data-sort-value="7000412000000000000♠">
#             4.12
#            </span>
#           </p>
#          </td>
#          <td>
#           <span data-sort-value="7001497000000000000♠">
#            49.7
#           </span>
#           %
#          </td>
#          <td>
#           <span data-sort-value="000000002019-03-01-0000" style="white-space:nowrap">
#            1 March 2019
#           </span>
#           <p>
#            <br/>
#           </p>
#          </td>
#         </tr>
#         <tr>
#          <td>
#           <span class="flagicon">
# ...
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_countries_by_minimum_wage" title="List of all English Wikipedia pages containing links to this page [j]">
#          <span>
#           What links here
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_countries_by_minimum_wage" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          <span>
#           Related changes
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          <span>
#           Upload file
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          <span>
#           Special pages
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-permalink">
#         <a href="/w/index.php?title=List_of_countries_by_minimum_wage&amp;oldid=1058933720" title="Permanent link to this revision of this page">
#          <span>
#           Permanent link
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-info">
#         <a href="/w/index.php?title=List_of_countries_by_minimum_wage&amp;action=info" title="More information about this page">
#          <span>
#           Page information
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_countries_by_minimum_wage&amp;id=1058933720&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">
#          <span>
#           Cite this page
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1153034" title="Structured data on this page hosted by Wikidata [g]">
#          <span>
#           Wikidata item
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-coll-print_export-label">
#       <span>
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_countries_by_minimum_wage&amp;action=show-download-screen" title="Download this page as a PDF file">
#          <span>
#           Download as PDF
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-print">
#         <a accesskey="p" href="/w/index.php?title=List_of_countries_by_minimum_wage&amp;printable=yes" title="Printable version of this page [p]">
#          <span>
#           Printable version
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-lang-label">
#       <span>
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="interlanguage-link interwiki-ar mw-list-item">
#         <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A7%D9%84%D8%AF%D9%88%D9%84_%D8%AD%D8%B3%D8%A8_%D8%A7%D9%84%D8%AD%D8%AF_%D8%A7%D9%84%D8%A3%D8%AF%D9%86%D9%89_%D9%84%D9%84%D8%A3%D8%AC%D9%88%D8%B1" hreflang="ar" lang="ar" title="قائمة الدول حسب الحد الأدنى للأجور – Arabic">
#          <span>
#           العربية
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-az mw-list-item">
#         <a class="interlanguage-link-target" href="https://az.wikipedia.org/wiki/Minimum_%C9%99m%C9%99khaqq%C4%B1na_g%C3%B6r%C9%99_%C3%B6lk%C9%99l%C9%99rin_siyah%C4%B1s%C4%B1" hreflang="az" lang="az" title="Minimum əməkhaqqına görə ölkələrin siyahısı – Azerbaijani">
#          <span>
#           Azərbaycanca
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ca mw-list-item">
#         <a class="interlanguage-link-target" href="https://ca.wikipedia.org/wiki/Llista_de_pa%C3%AFsos_per_SMI" hreflang="ca" lang="ca" title="Llista de països per SMI – Catalan">
#          <span>
#           Català
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fa mw-list-item">
#         <a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D8%AD%D8%AF%D8%A7%D9%82%D9%84_%D8%AF%D8%B3%D8%AA%D9%85%D8%B2%D8%AF_%DA%A9%D8%B4%D9%88%D8%B1%D9%87%D8%A7%DB%8C_%D9%85%D8%AE%D8%AA%D9%84%D9%81_%D8%AC%D9%87%D8%A7%D9%86" hreflang="fa" lang="fa" title="فهرست حداقل دستمزد کشورهای مختلف جهان – Persian">
#          <span>
#           فارسی
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-id mw-list-item">
#         <a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Daftar_negara_menurut_upah_minimum_per_tahun" hreflang="id" lang="id" title="Daftar negara menurut upah minimum per tahun – Indonesian">
#          <span>
#           Bahasa Indonesia
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ja mw-list-item">
#         <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/%E5%90%84%E5%9B%BD%E3%81%AE%E6%9C%80%E4%BD%8E%E8%B3%83%E9%87%91%E3%81%AE%E4%B8%80%E8%A6%A7" hreflang="ja" lang="ja" title="各国の最低賃金の一覧 – Japanese">
#          <span>
#           日本語
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pnb mw-list-item">
#         <a class="interlanguage-link-target" href="https://pnb.wikipedia.org/wiki/%D9%84%D8%B3%D9%B9_%DA%AF%DA%BE%D9%B9_%D8%AA%D9%88%DA%BA_%DA%AF%DA%BE%D9%B9_%D8%A7%D8%AC%D8%B1%D8%AA_%D8%A8%D9%84%D8%AD%D8%A7%D8%B8_%D8%AF%DB%8C%D8%B3" hreflang="pnb" lang="pnb" title="لسٹ گھٹ توں گھٹ اجرت بلحاظ دیس – Western Punjabi">
#          <span>
#           پنجابی
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt mw-list-item">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Lista_de_sal%C3%A1rios_m%C3%ADnimos_por_pa%C3%ADs" hreflang="pt" lang="pt" title="Lista de salários mínimos por país – Portuguese">
#          <span>
#           Português
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru mw-list-item">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D1%81%D1%82%D1%80%D0%B0%D0%BD_%D0%BC%D0%B8%D1%80%D0%B0_%D0%BF%D0%BE_%D0%BC%D0%B8%D0%BD%D0%B8%D0%BC%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D0%BC%D1%83_%D1%80%D0%B0%D0%B7%D0%BC%D0%B5%D1%80%D1%83_%D0%BE%D0%BF%D0%BB%D0%B0%D1%82%D1%8B_%D1%82%D1%80%D1%83%D0%B4%D0%B0" hreflang="ru" lang="ru" title="Список стран мира по минимальному размеру оплаты труда – Russian">
#          <span>
#           Русский
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-th mw-list-item">
#         <a class="interlanguage-link-target" href="https://th.wikipedia.org/wiki/%E0%B8%A3%E0%B8%B2%E0%B8%A2%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%80%E0%B8%A3%E0%B8%B5%E0%B8%A2%E0%B8%87%E0%B8%95%E0%B8%B2%E0%B8%A1%E0%B8%84%E0%B9%88%E0%B8%B2%E0%B9%81%E0%B8%A3%E0%B8%87%E0%B8%82%E0%B8%B1%E0%B9%89%E0%B8%99%E0%B8%95%E0%B9%88%E0%B8%B3" hreflang="th" lang="th" title="รายชื่อประเทศเรียงตามค่าแรงขั้นต่ำ – Thai">
#          <span>
#           ไทย
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk mw-list-item">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D0%BC%D1%96%D0%BD%D1%96%D0%BC%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D0%B3%D0%BE_%D1%80%D0%BE%D0%B7%D0%BC%D1%96%D1%80%D1%83_%D0%BE%D0%BF%D0%BB%D0%B0%D1%82%D0%B8_%D0%BF%D1%80%D0%B0%D1%86%D1%96_%D0%B7%D0%B0_%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%BE%D1%8E" hreflang="uk" lang="uk" title="Список мінімального розміру оплати праці за країною – Ukrainian">
#          <span>
#           Українська
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ur mw-list-item">
#         <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D9%81%DB%81%D8%B1%D8%B3%D8%AA_%DA%A9%D9%85_%D8%A7%D8%B2_%DA%A9%D9%85_%D8%A7%D8%AC%D8%B1%D8%AA_%D8%A8%D9%84%D8%AD%D8%A7%D8%B8_%D9%85%D9%84%DA%A9" hreflang="ur" lang="ur" title="فہرست کم از کم اجرت بلحاظ ملک – Urdu">
#          <span>
#           اردو
#          </span>
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh mw-list-item">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E5%90%84%E5%9C%8B%E6%9C%80%E4%BD%8E%E5%B7%A5%E8%B3%87%E5%88%97%E8%A1%A8" hreflang="zh" lang="zh" title="各國最低工資列表 – Chinese">
#          <span>
#           中文
#          </span>
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1153034#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 6 December 2021, at 13:11
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_countries_by_minimum_wage&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"11.550","walltime":"12.187","ppvisitednodes":{"value":500565,"limit":1000000},"postexpandincludesize":{"value":847624,"limit":2097152},"templateargumentsize":{"value":222475,"limit":2097152},"expansiondepth":{"value":22,"limit":40},"expensivefunctioncount":{"value":3,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":646139,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00% 11232.091      1 -total"," 80.44% 9035.173    152 Template:List_of_minimum_wages_by_country/Row"," 42.51% 4774.356    788 Template:Nts"," 39.40% 4424.906    665 Template:To_USD"," 24.00% 2695.779    559 Template:To_USD/General"," 23.70% 2662.281    152 Template:List_of_minimum_wages_by_country/Annual_wage/USD"," 19.62% 2204.158    558 Template:To_USD/data/2019"," 14.52% 1630.648    152 Template:List_of_minimum_wages_by_country/Hourly_wage/USD"," 13.91% 1562.420    152 Template:List_of_minimum_wages_by_country/GDP_per_capita"," 10.44% 1173.164      2 Template:Reflist"]},"scribunto":{"limitreport-timeusage":{"value":"2.020","limit":"10.000"},"limitreport-memusage":{"value":7515547,"limit":52428800},"limitreport-profile":[["Scribunto_LuaSandboxCallback::getExpandedArgument","4440","72.1"],["?","360","5.8"],["recursiveClone \u003CmwInit.lua:41\u003E","280","4.5"],["Scribunto_LuaSandboxCallback::callParserFunction","160","2.6"],["Scribunto_LuaSandboxCallback::find","140","2.3"],["Scribunto_LuaSandboxCallback::gsub","100","1.6"],["(for generator) \u003Cmw.lua:680\u003E","80","1.3"],["(for generator)","80","1.3"],["Scribunto_LuaSandboxCallback::formatNum","80","1.3"],["Scribunto_LuaSandboxCallback::plain","40","0.6"],["[others]","400","6.5"]]},"cachereport":{"origin":"mw1453","timestamp":"20211206140654","ttl":1814400,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of countries by minimum wage","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_countries_by_minimum_wage","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1153034","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1153034","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2006-03-21T23:45:25Z","dateModified":"2021-12-06T13:11:17Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/c\/ca\/Minimum_wages_by_territory.png","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":192,"wgHostname":"mw1330"});});
#   </script>
#  </body>
# </html>

# %%
# /html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr[187]/td[3]/span
# min_wage_data_text = soup.find_all('tr', {"id" : re.compile('row*')})
# min_wage_data_text[1]
min_wage_data_text = soup.find_all('tr')
min_wage_data_text[5].text.split('\n')
# Out:
# ['',
#  '\xa0Algeria',
#  '',
#  '20,000 Algerian dinars ($156.19) per month, nationally.[14][15]',
#  '',
#  '2,010',
#  '',
#  '',
#  '6,247',
#  '',
#  '',
#  '40',
#  '',
#  '0.97',
#  '',
#  '',
#  '3',
#  '',
#  '',
#  '41.6%',
#  '',
#  '1 May 2020',
#  '']

# %%
# country_names = soup.find_all(class_=re.compile('RowDimLab.*'))
# country_names[0]
min_wage_countries_list = []
for country in min_wage_data_text:
    if len(country) == 18:
        print(country.get_text())
        print(len(country.get_text().split('\n')))
        min_wage_countries_list.append(country.get_text().split('\n'))
#min_wage_countries_list
# Out:
#  Afghanistan
#
# 5,500 Afghani ($67) per month for non-permanent private sector. The minimum wage for permanent government workers was 6,000 Afghanis ($74) per month. There was no minimum wage for permanent workers in the private sector.[10]
#
# 866
#
#
# 3,272
#
#
# 40
#
# 0.42
#
#
# 1.57
#
#
# 168.3%
#
# 2017
#
#
#
# 25
#
#  Albania
#
# 30,000 Albanian lekë ($280) per month, in private sector and 37,000 lekë ($332) per month in public sector. The law establishes a 40-hour workweek, but the actual workweek is typically set by individual or collective-bargaining agreement.[10][11][12][13]
#
# 3,277
#
#
# 6,523
#
#
# 40
#
# 1.58
#
#
# 3.14
#
#
# 56.5%
#
# 5 May 2017
#
#
#
# 25
#
#  Algeria
#
# 20,000 Algerian dinars ($156.19) per month, nationally.[14][15]
#
# 2,010
#
#
# 6,247
#
#
# 40
#
# 0.97
#
#
# 3
#
#
# 41.6%
#
# 1 May 2020
#
# 23
#
#  Andorra
#
# €1050.40 per month, €6.06 per hour.[16]
#
# 14,397
#
# 11,020
#
# 40
#
# 6.72
#
# 5.3
#
# 28%
#
# 1 January 2019
#
#
#
# 21
#
#  Angola
#
# 21,454 kwanza ($58) per month; paid thirteen times a year.[17][18]
#
# 764
#
#
# 2,108
#
#
# 44
#
# 0.33
#
#
# 0.92
#
#
# 32.7%
#
# 1 April 2019
#
#
#
# 25
#
#  Antigua and Barbuda
#
# EC$8.20 per hour (US$3.03).[10][19][20]
#
# 6,317
#
#
# 7,788
#
#
# 40
#
# 3.04
#
#
# 3.74
#
#
# 34.4%
#
# 1 November 2014
#
#
#
# 25
#
#  Argentina
#
# 32,000 Argentine pesos ($305) per month for up to 200 hours; paid thirteen times a year.[21][22]
#
# 8,640
#
#
# 44,645
#
#
# 48
#
# 3.46
#
#
# 17.89
#
#
# 223.9%
#
# 1 November 2021
#
#
#
# 25
#
#  Armenia
#
# 68,000 Armenian dram ($143) per month.[10][23]
#
# 1,698
#
#
# 4,140
#
#
# 40
#
# 0.82
#
#
# 1.99
#
#
# 46.9%
#
# 1 July 2019
#
#
#
# 25
#
#  Australia
#
# Most workers are covered by an award, which may vary by employee age, geographical location and industry. Workers receive mandatory employer superannuation contributions of at least 10% (increasing to 12% by 2025) of wages, alongside loadings such as penalty rates or leave loading. Minimum wages are set federally by the Fair Work Commission.
# For those 21 and older, not covered by an award or other instrument, the minimum wages is A$772.60 ($568.34 USD) per week, or A$20.33 ($14.95 USD) per hour.[24] Casual workers are paid a loading of typically 25%, resulting in a minimum of A$24.80 per hour for those workers.
# Workers under 21, apprentices and trainees not covered by an award, have a minimum wages set at a percentage of the ordinary rate.[24] For those under 16, this is 36.8% or A$7.30 per hour; A$9.13 with the casual loading.[25]
#
#
# 28,734
#
#
# 25,110
#
#
# 38
#
# 14.54
#
#
# 12.71
#
#
# 54.6%
#
# 1 July 2021
#
# 26
#
#  Austria
#
# None; National collective bargaining agreements set minimum wages by job classification for each industry and provide for a minimum wage of €1,200 ($1,289) per month[dubious  – discuss]. Wages where no such collective agreements exist, such as for domestic workers, janitorial staff and au pairs, are regulated by relevant legislation and are generally lower than those covered by collective bargaining. The national minimum wage legislation has lapsed, although is still in force by convention.[26][10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Azerbaijan
#
# 250 Azerbaijani manat (146$) per month.[27][28]
#
# 1,765
#
#
# 8,571
#
#
# 40
#
# 0.85
#
#
# 4.12
#
#
# 49.7%
#
# 1 March 2019
#
#
#
# 25
#
#  The Bahamas
#
# B$5.25 ($5.25) per hour, B$42 ($42) per day, and B$210 ($210) per week.[10][29][30]
#
# 10,920
#
#
# 9,579
#
#
# 40
#
# 5.25
#
#
# 4.61
#
#
# 42.5%
#
# 15 August 2015
#
# 23
#
#  Bahrain
#
# None; 300 BHD ($800) for the public sector workers (only applies to Bahraini nationals).[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Bangladesh
#
# 1,500 taka ($19) per month for all economic sectors not covered by industry-specific wages; in the garment industry the minimum wage raised to 8,000 taka ($95) per month since 1 December 2018.[31] The minimum wage is set nationally every five years by the National Minimum Wage Board in a tripartite forum industry by industry.[10][18][32][33][34]
#
# 214
#
#
# 564
#
#
# 48
#
# 0.09
#
#
# 0.23
#
#
# 15.8%
#
# 1 December 2013
#
#
#
# 25
#
#  Barbados
#
# BDS$6.25 ($3.13) per hour for household domestics and shop assistants; the Ministry of Labor recommends all other sectors use this as the de facto minimum wage.[10][35]
#
# 6,500
#
#
# 5,285
#
#
# 40
#
# 3.13
#
#
# 2.54
#
#
# 29.3%
#
# 1 March 2012
#
#
#
# 25
#
#  Belarus
#
# 400.00 BYNs per month.[36]
#
# 0
#
#
# 1
#
#
# 40
#
# 0
#
#
# 0
#
#
# 0%
#
# 1 January 2021
#
#
#
# 25
#
#  Belgium
#
# €1,593.81 per month.[37][18][38]
#
# 21,845
#
#
# 21,734
#
#
# 38
#
# 11.06
#
#
# 11
#
#
# 46.8%
#
# 1 January 2019
#
#
#
# 25
#
#  Belize
#
# BZ$3.30 ($1.65) per hour.[10][39][40]
#
# 3,861
#
#
# 6,774
#
#
# 45
#
# 1.65
#
#
# 2.89
#
#
# 80.1%
#
# 26 May 2012
#
#
#
# 25
#
#  Benin
#
# 40,000 CFA francs ($70) per month; the government set minimum wage scales for a number of occupations.[18][41]
#
# 819
#
#
# 2,149
#
#
# 40
#
# 0.39
#
#
# 1.03
#
#
# 99.1%
#
# 1 April 2014
#
#
#
# 25
#
#  Bhutan
#
# 3,750 Bhutanese ngultrum per month.[10][42][43]
#
# 639
#
#
# 2,020
#
#
# 40
#
# 0.31
#
#
# 0.97
#
#
# 22.7%
#
# 1 February 2014
#
#
#
# 25
#
#  Bolivia
#
# 2122 Bolivian bolivianos ($300) per month.[44] plus an obligatory Christmas bonus equal to one month's pay, prorated for the amount of time the worker has worked in their present position. Plus a second Christmas Bonus if the government decries the economy grew enough, plus an extra month paid in May if the company made a profit for the previous year.[45][46]
#
# 4,071
#
#
# 8,178
#
#
# 48
#
# 1.63
#
#
# 3.28
#
#
# 113%
#
# 1 May 2021
#
#
#
# 25
#
#  Bosnia and Herzegovina
#
# 406 convertible marks ($240) net per month.[47]
#
# 2,789
#
#
# 6,015
#
#
# 40
#
# 1.34
#
#
# 2.89
#
#
# 49.4%
#
# 2015
#
#
#
# 25
#
#  Botswana
#
# 5.46 Botswana pula ($0.58) an hour for most full-time labor in the private sector; 3.03 ($.29) Botswana pula per hour for domestic workers or approximately 24.24 pula ($2.28) a day; 620 Botswana pula ($60) per month for workers in the agriculture sector.[10][18]
#
# 692
#
#
# 1,406
#
#
# 48
#
# 0.28
#
#
# 0.56
#
#
# 8.3%
#
# 1 June 2016
#
#
#
# 25
#
#  Brazil
#
# 1,100 Brazilian reais per month ($ 210.18), paid 13 times a year.[48] The Brazilian minimum wage is adjusted annually by the federal government. Each Brazilian state has its own minimum wage, which cannot be lower than the federal minimum wage.
#
# 3,625
#
#
# 6,530
#
#
# 44
#
# 1.58
#
#
# 2.85
#
#
# 43.2%
#
# 1 January 2021
#
# 23
#
#  Brunei
#
# None[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Bulgaria
#
# 650 Bulgarian lev (€332) per month, 3.86 lev (€1.97) per hour.[37][49][50][51]
#
# 4,596
#
#
# 10,705
#
#
# 40
#
# 2.21
#
#
# 5.15
#
#
# 55.6%
#
# 1 January 2021
#
#
#
# 25
#
#  Burkina Faso
#
# 34,664 CFA francs ($59) per month.[10][52]
#
# 710
#
#
# 1,905
#
#
# 40
#
# 0.34
#
#
# 0.92
#
#
# 107.6%
#
# 1 April 2012
#
# 23
#
#  Burundi
#
# None; in the past the government set the minimum wage, but during the year the minimum wage was set by market forces.[10][41]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2017
#
# 19
#
#  Cambodia
#
# US$182 per month, for the garment and shoe industry.[53][10][18]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 1 January 2019
#
#
#
# 21
#
#  Cameroon
#
# 36,270 CFA francs ($62) per month.[10][54]
#
# 743
#
#
# 1,819
#
#
# 40
#
# 0.36
#
#
# 0.87
#
#
# 50.4%
#
# 30 July 2014
#
#
#
# 25
#
#  Canada
#
# The minimum wage in Canada is set by each province and territory; ranges from $11.32 to $16 CAD per hour. The minimum wage  calculated here is a weighted average based on the relative population in each province.[10][55][56]
#
# 21,477
#
#
# 20,953
#
#
# 40
#
# 10.33
#
#
# 10.07
#
#
# 46.7%
#
# 1 June 2020
#
#
#
# 25
#
#  Cape Verde
#
# 13,000 Cape Verdean escudos ($141) per month.[57][58]
#
# 1,584
#
#
# 3,414
#
#
# 44
#
# 0.69
#
#
# 1.49
#
#
# 52.1%
#
# 1 January 2018
#
#
#
# 25
#
#  Central African Republic
#
# 35,000 CFA francs per month, 218.75 CFA francs per hour.[59][60]
#
# 777
#
#
# 1,392
#
#
# 40
#
# 0.37
#
#
# 0.67
#
#
# 199.3%
#
# 2011
#
#
#
# 25
#
#  Chad
#
# 59,995 CFA francs ($110) per month, 355 CFA francs ($0.6) per hour.[10][61][62]
#
# 1,229
#
#
# 3,484
#
#
# 39
#
# 0.61
#
#
# 1.72
#
#
# 175%
#
# 18 October 2011
#
#
#
# 25
#
#  Chile
#
# 337,000 Chilean pesos ($440) per month for workers aged 18–65; or 243,561 pesos ($318) per month for workers younger than 18 and older than 65; and 210,458 pesos ($260) per month for 'non remunerative' purposes.[63]
#
# 5,753
#
#
# 8,886
#
#
# 45
#
# 2.46
#
#
# 3.8
#
#
# 38.3%
#
# 7 July 2021
#
#
#
# 25
#
#  China
#
# The minimum wage in China is set locally; ranges from RMB1,120 ($161.07) per month, or RMB10.60 ($1.52) per hour in Liaoning; to RMB2,420 ($348.02) per month, or RMB21.00 ($3.02) per hour in Shanghai.[18][64][65][66][67]
#
# 1,945
#
#
# 3,491
#
#
# 40
#
# 0.94
#
#
# 1.68
#
#
# 22.5%
#
# 31 July 2018
#
#
#
# 25
#
#  Colombia
#
# 908 526 Colombian pesos + 106 454 by transportation subsidy ($290) per month[68]
#
# 4,022
#
#
# 9,620
#
#
# 48
#
# 1.61
#
#
# 3.85
#
#
# 68%
#
# 1 January 2021
#
#
#
# 25
#
#  Comoros
#
# 55,000 Comorian francs ($129) per month.[10]
#
# 1,502
#
#
# 3,037
#
#
# 40
#
# 0.72
#
#
# 1.46
#
#
# 199.5%
#
# 2017
#
#
#
# 25
#
#  Democratic Republic of the Congo
#
# 1,680 Congolese francs ($1.83) per day.[10][69]
#
# 265
#
#
# 741
#
#
# 45[70]
#
# 0.11
#
#
# 0.32
#
#
# 92.4%
#
# 1 January 2009
#
#
#
# 25
#
#  Republic of the Congo
#
# 90,000 CFA francs ($170) per month in the formal sector.[10]
#
# 1,843
#
#
# 6,958
#
#
# 40
#
# 0.89
#
#
# 3.35
#
#
# 121.7%
#
# 2017
#
#
#
# 25
#
#  Costa Rica
#
# Varies for specified industries from ₡10,060.75 ($16.73) per 8-hour work day for all workers to ₡13,141.39 ($23) per day for specialized workers. All other occupations not explicitly covered fall under the generic scale, which varies from ₡300,255.79 ($528) per month for unskilled workers to ₡644,689.30 ($1134) per month for licentiates.[71][72]
#
# 6,496
#
#
# 10,221
#
#
# 48
#
# 2.6
#
#
# 4.1
#
#
# 61.5%
#
# 1 January 2021
#
#
#
# 25
#
#  Côte d'Ivoire
#
# Varies by occupation, with the lowest set to 36,607 CFA franc ($72) per month for the industrial sector; a slightly higher minimum wage rate is applied for construction workers.[10][73][74]
#
# 750
#
#
# 1,868
#
#
# 40
#
# 0.36
#
#
# 0.9
#
#
# 50.6%
#
# 1994
#
#
#
# 25
#
#  Croatia
#
# The minimum wage in Croatia is 3,750 Croatian kuna per month. ($566) [18][75]
#
# 6,795
#
#
# 11,250
#
#
# 40
#
# 3.27
#
#
# 5.41
#
#
# 48%
#
# 1 January 2019
#
# 23
#
#  Cuba
#
# 2100 Cuban pesos ($80) per month.[76] Each citizen is however also given free food to supplement the salary.
#
# 1,050
#
# 669
#
# 48
#
# 0.44
#
# 0.74
#
# 0.4%
#
# 2021
#
# 19
#
#  Cyprus
#
# None; €870 ($1006) per month for shop assistants, nurses' assistants, clerks, hairdressers, and nursery assistants; it rises to €924 ($1069) after six months' employment. For asylum seekers working as unskilled workers in the agricultural sector, the minimum monthly wage was 425 euros ($570) with accommodation and food provided. For skilled workers in the agricultural sector, the minimum salary was 767 euros ($1040) without accommodation and food.[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Czech Republic
#
# 14,600.00 Czech koruna per month, ($637) or 87.30 koruna per hour.[77][18][78]
#
# 7,918
#
#
# 12,716
#
#
# 40
#
# 3.81
#
#
# 6.11
#
#
# 36.6%
#
# 1 January 2020
#
# 23
#
#  Denmark
#
# None; instead, negotiated between unions and employer associations; the average minimum wage for all private and public sector collective bargaining agreements was approximately DKK 110 (nominally $16) per hour, exclusive of pension benefits.[10][79]
#
#
#
#
#
# 37.5
#
#
#
#
#
#
#
# 2017
#
# 19
#
#  Djibouti
#
# None; canceled by the 2006 Labor Code for occupational categories, establishing that wages be set after common agreement between employers and employees. For public sector workers, minimum wage was 35,000 DFJ ($198) per month.[10][80]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Dominica
#
# EC$4.00 ($1.50) per hour.[10][81][82]
#
# 3,081
#
#
# 4,223
#
#
# 40
#
# 1.48
#
#
# 2.03
#
#
# 38.6%
#
# 1 June 2008
#
#
#
# 25
#
#  Dominican Republic
#
# 8,310Dominican pesos ($166) per month in the FTZs and between 9,412 pesos ($188) and 15,448 pesos ($309) outside the FTZs, depending upon the size of the company; 5,884 pesos ($117) per month for the public sector; 320 pesos ($6) a day for farm workers who are covered by minimum wage regulations based on a 10-hour day, with the exception of sugarcane workers who received 146 pesos based on an eight-hour workday.[10][83][84]
#
# 2,915
#
#
# 6,704
#
#
# 44
#
# 1.27
#
#
# 2.93
#
#
# 44.1%
#
# 2021
#
#
#
# 25
#
#  Ecuador
#
# US$466.66 per month (for month average, including proportional 13th and 14th salaries and minimal 15 days vacation period). The minimum wage has been set by the government at $400, per month without social benefits for the year 2020, but a worker also receives mandatory 13rd and a 14th salary.[85]
#
# 5,200
#
#
# 8,525
#
#
# 40
#
# 2.5
#
#
# 4.1
#
#
# 75.8%
#
# 1 January 2020
#
# 23
#
#  Egypt
#
# None; for the public sector the minimum wage is LE1,200 ($68) per month.[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  El Salvador
#
# The minimum wage was set by the government at $304.17 monthly in 2018.[10][18][86]
#
# 3,650
#
#
# 7,019
#
#
# 44
#
# 1.6
#
#
# 3.07
#
#
# 81.5%
#
# 1 January 2018
#
#
#
# 25
#
#  Equatorial Guinea
#
# 129,035 CFA franc ($224) per month.[10]
#
# 2,643
#
#
# 4,479
#
#
# 48
#
# 1.06
#
#
# 1.79
#
#
# 17.2%
#
# 2017
#
# 23
#
#  Eritrea
#
# None; 360 Eritrean nakfa ($23.3) per month in the public sector.[10]
#
#
#
#
#
# 44.5
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Estonia
#
# €584 per month, or €3.48 per hour.[87][18]
#
# 7,626
#
#
# 10,946
#
#
# 40
#
# 3.67
#
#
# 5.26
#
#
# 36.8%
#
# 1 January 2020
#
# 23
#
#  Eswatini
#
# 531.6 Swazi emalangeni ($76.50) per month for a domestic worker; 420 emalangeni ($60.50) a month for an unskilled worker; 600 emalangeni ($86.50) a month for a skilled worker.[80]
#
# 694
#
# 1,128
#
# 48
#
# 0.33
#
# 0.54
#
# 19%
#
# 2011
#
# 19
#
#  Ethiopia
#
# None; some government institutions and public enterprises set their own minimum wages: public sector employees, the largest group of wage earners, earned a monthly minimum wage of 420 Ethiopian birr ($21); employees in the banking and insurance sector had a minimum monthly wage of 336 birr ($18).[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
# 19
#
#  Federated States of Micronesia
#
# None; US$2.65 per hour for employment with the national government; all states have a minimum hourly wage for government workers: $2.00 in Pohnpei, $1.25 in Chuuk, $1.42 in Kosrae, and $1.60 in Yap; $1.75 for private sector workers in Pohnpei.[10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2015
#
#
#
# 21
#
#  Fiji
#
# FJ$2.68 per hour.[88][89]
#
# 3,096
#
#
# 5,226
#
#
# 48
#
# 1.24
#
#
# 2.09
#
#
# 57.4%
#
# 30 September 2017
#
# 23
#
#  Finland
#
# None; however, the law requires all employers, including non-unionized ones, to pay minimum wages agreed to in collective bargaining agreements; almost all workers are covered under such arrangements.[10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  France
#
# €1,589.47 ($1815) gross per month, €10.48 ($11.97) per hour.[90]
#
# 21,786
#
#
# 21,924
#
#
# 35
#
# 11.97
#
#
# 12.05
#
#
# 53%
#
# 1 January 2021
#
#
#
# 25
#
#  Gabon
#
# 150,000 CFA francs ($255) per month; government workers received an additional monthly allowance of 20,000 CFA francs ($34) per child; government workers also received transportation, housing, and family benefits; the law does not mandate housing or family benefits for private sector workers.[10][91]
#
# 3,072
#
#
# 4,865
#
#
# 40
#
# 1.48
#
#
# 2.34
#
#
# 26.9%
#
# 1 February 2010
#
#
#
# 25
#
#  The Gambia
#
# 50 dalasi ($1.25) per day.[10]
#
# 260
#
#
# 958
#
#
# 48
#
# 0.1
#
#
# 0.38
#
#
# 57.1%
#
# 2017
#
#
#
# 25
#
#  Georgia
#
# 20 Georgian lari ($8) per month for private sector workers which has remained unchanged since the early 1990s but is not applied in practice; 115 lari ($48) per month for public employees.[10]
#
# 106
#
#
# 353
#
#
# 40
#
# 0.05
#
#
# 0.17
#
#
# 3.5%
#
# 2017
#
#
#
# 25
#
#  Germany
#
# €9.35 ($10.68) per hour is the minimum wage in Germany. A higher minimum wage is often set by collective bargaining agreements and enforceable by law.[18]
#
# 22,214
#
#
# 23,431
#
#
# 40[92]
#
# 10.68
#
#
# 11.27
#
#
# 48%
#
# 1 January 2020
#
#
#
# 25
#
#  Ghana
#
# 9.68 Ghanaian cedis ($1.7) per day.[18][10][93]
#
# 482
#
#
# 1,760
#
#
# 40
#
# 0.23
#
#
# 0.85
#
#
# 41%
#
# 1 January 2018
#
#
#
# 25
#
#  Greece
#
# €758 ($853) per month in 12 payments, €650 ($732) per month in 14 payments, or €5.71 ($6.51) per hour.[37][94]
#
# 10,389
#
#
# 13,376
#
#
# 40
#
# 4.99
#
#
# 6.43
#
#
# 50%
#
# 1 February 2019
#
# 23
#
#  Grenada
#
# Minimum wage schedules set pay by occupation; for example, the minimum wage for domestic workers, for example, was EC$4.50 per hour, while that for a security guard was EC$8.00 per hour.[10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Guatemala
#
# 81.87 Guatemalan quetzales ($10.9) per day for agricultural and nonagricultural work and 74.89 quetzales ($10.0) per day for work in export-sector regime factories. Minimum wage earners also are due a mandatory monthly bonus of 250 quetzales ($33), and salaried workers receive two mandatory yearly bonuses (the bono 14 and the Christmas bonus), each equivalent to one month's salary.[10][18]
#
# 3,941
#
#
# 6,974
#
#
# 48
#
# 1.58
#
#
# 2.79
#
#
# 87.8%
#
# 1 January 2016
#
# 23
#
#  Guernsey
#
# £8.70 per hour ($11.60) for those aged 18+  £8.25 per hour ($11.00) for those aged 17–18.[95]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1 January 2021
#
# 19
#
#  Guinea
#
# The labor code allows the government to set a minimum hourly wage; however, the government has not exercised this provision except for setting the minimum wage for domestic workers at 440,000 GNF ($62) per month.[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  Guinea-Bissau
#
# 19,030 CFA francs ($30) per month plus a bag of rice[10]
#
# 390
#
#
# 935
#
#
# 45
#
# 0.17
#
#
# 0.4
#
#
# 58.1%
#
# 2017
#
#
#
# 25
#
#  Guyana
#
# G$35,000 ($168 USD) per month, or G$1,616 ($7 USD) per day, or G$202 ($1 USD) per hour.[96]
#
# 2,015
#
#
# 3,204
#
#
# 40
#
# 0.97
#
#
# 1.54
#
#
# 40.9%
#
# 1 July 2013
#
#
#
# 25
#
#  Haiti
#
# 290 Haitian gourdes per day for servants for an eight-hour workday; 400 Haitian gourdes per day for segment A industries; 350 Haitian gourdes per day for segment B industries; 290 Haitian gourdes per day for segment C industries; 350 Haitian gourdes per day for companies with piece work that re-export; and 350 Haitian gourdes per day for companies with piece work that exports.[97][10][98][99][100]
#
# 1,075
#
#
# 3,194
#
#
# 48
#
# 0.43
#
#
# 1.28
#
#
# 179.1%
#
# 1 August 2017
#
#
#
# 25
#
#  Honduras
#
# Minimum wages ranged from a low of 6,096.71 Honduran lempiras per month, 25.41 lempiras per hour to 10,698.30 lempiras per month, 44.58 lempiras per hour.[10][18][101]
#
# 2,372
#
#
# 4,948
#
#
# 44
#
# 1.04
#
#
# 2.16
#
#
# 104.5%
#
# 1 January 2018
#
#
#
# 25
#
#  Hong Kong
#
# HK$37.50 (US$4.8) per hour is the minimum wage in Hong Kong.[102]
#
# 9,954
#
#
# 12,093
#
#
# 40
#
# 4.79
#
#
# 5.81
#
#
# 20.6%
#
# 1 May 2019
#
#
#
# 25
#
#  Hungary
#
# 161,000 HUF ($554) per month for unskilled labor, 210,600 HUF ($725) per month for skilled labor.[18][103][104][105][106]
#
# 6,647
#
#
# 12,933
#
#
# 40
#
# 3.2
#
#
# 6.22
#
#
# 48.4%
#
# 1 January 2020
#
# 23
#
#  Iceland
#
# None; minimum wages are negotiated in various collectively bargained agreements and applied automatically to all employees in those occupations, regardless of union membership; while the agreements can be either industry- or sector-wide, and in some cases firm-specific, the minimum wage levels are occupation-specific.[10][37]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2017
#
#
#
# 21
#
#  India
#
# Though stipulated by law, it varies from 160 rupees ($2.27) per day in Bihar, Rs. 348/day ($4.94) in Mumbai (2017)[107] 750 rupees ($11) per day in Kerala. State governments set a separate minimum wage for agricultural workers.[10] The minimum wages are set according to Minimum Wages Act, 1948.[108]
#
# 709
#
#
# 2,498
#
#
# 48
#
# 0.28
#
#
# 1
#
#
# 38%
#
# 2015
#
#
#
# 25
#
#  Indonesia
#
# Established by provincial and district authorities, which vary by province, district, and sector; the lowest minimum wage is in the province of Yogyakarta at rupiah 1,704,608 (US$121) per month and the highest is in Jakarta at rupiah 4,276,349 (US$303) per month.[18]
# [109]
#
#
# 2,477
#
#
# 7,028
#
#
# 40
#
# 1.19
#
#
# 3.38
#
#
# 60.5%
#
# 1 February 2020
#
#
#
# 27
#
#  Iran
#
# 2,655,495 Iranian tomans (equal to 26,554,950 rials), and to ($106) per month effective on the 2021 Persian New year;[110] set annually for each industrial sector and region. The standard workweek is 44 hours, and any work over 48 entitles the worker to overtime.[10]
#
# 1,275
#
#
# 8,812
#
#
# 44[111]
#
# 0.56
#
#
# 3.85
#
#
# 47.6%
#
# 21 March 2021
#
#
#
# 25
#
#  Iraq
#
# 250,000 Iraqi dinars ($214) per month.[10]
#
# 2,538
#
#
# 5,222
#
#
# 40
#
# 1.22
#
#
# 2.51
#
#
# 30.1%
#
# 2014
#
#
#
# 25
#
#  Ireland
#
# €10.10 ($11.54) per hour, with sub-minimal rates for those under 18 (70% of minimum), and for those over 18 in first year of employment (80%), in second year of employment (90%).
# [112]
# Eurostat calculates the monthly rate for Ireland as (hourly rate x 39 hours x 52 weeks) / 12 months [113]
#
#
# 23,395
#
#
# 20,483
#
#
# 39
#
# 11.54
#
#
# 10.1
#
#
# 28.7%
#
# 1 February 2020
#
# 26
#
#  Isle of Man
#
# £8.25 per hour ($10.18) for those aged 18+  £6.15 per hour ($7.59) for those aged under 18  £7.30 per hour ($9.01) for development worker.[114]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1 October 2019
#
# 19
#
#  Israel
#
# ₪5,300 ($1487) per month; or ₪29.12 ($8.17) per hour.[115][116]
#
# 17,842
#
#
# 14,389
#
#
# 42
#
# 8.17
#
#
# 6.59
#
#
# 38.6%
#
# 1 April 2018
#
# 23
#
#  Italy
#
# None; instead set generally through collective bargaining agreements on a sector-by-sector basis.[10][78]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2019
#
#
#
# 21
#
#  Jamaica
#
# J$7,000 ($53) per week.[117]
#
# 2,730
#
#
# 4,564
#
#
# 40
#
# 1.31
#
#
# 2.19
#
#
# 51.7%
#
# 1 August 2018
#
#
#
# 25
#
#  Japan
#
# Ranges from 820–1,041 Japanese yen ($7.52–$9.55) per hour; varies on a prefectural and industry basis.[118][119]
#
# 15,646
#
#
# 15,918
#
#
# 40
#
# 7.52
#
#
# 7.65
#
#
# 37.6%
#
# 8 October 2021
#
# 23
#
#  Jersey
#
# £8.32 per hour ($10.27) for those aged 18+  £7.28 per hour ($8.99) for trainees year 2.£6.02 per hour ($7.43) for trainees year 1.[120]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1 April 2020
#
# 19
#
#  Jordan
#
# 220 Jordanian dinars ($310) per month.[121]
#
# 5,408
#
#
# 11,636
#
#
# 48
#
# 2.17
#
#
# 4.66
#
#
# 128.6%
#
# 12 February 2017
#
#
#
# 25
#
#  Kazakhstan
#
# 28,284 Kazakhstani tenge ($78) per month is the minimum wage in Kazakhstan.[10][18][122]
#
# 887
#
#
# 2,987
#
#
# 40
#
# 0.43
#
#
# 1.44
#
#
# 11.8%
#
# 1 January 2018
#
#
#
# 25
#
#  Kenya
#
# Set by the government by location, age and skill level; the lowest agricultural minimum wage for unskilled employees was 6,415.55 Kenyan shillings per month, 269.40 per day, excluding housing allowance.[10][18][123][124]
#
# 755
#
#
# 1,656
#
#
# 52
#
# 0.28
#
#
# 0.61
#
#
# 52.5%
#
# 1 May 2017
#
#
#
# 25
#
#  Kiribati
#
# AUD$1.30 per hour for local businesses and companies, while the minimum wage for overseas-funded projects is AUD$3.00 an hour[10][125]
#
# 1,880
#
#
# 2,389
#
#
# 40
#
# 0.9
#
#
# 1.15
#
#
# 113.3%
#
# 1 November 2016
#
# 23
#
#  North Korea
#
# Averaging 5,000 – 10,000 North Korean won ($5.5 – $11.1) per day.[126]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2014
#
#
#
# 21
#
#  South Korea
#
# 8,590 won ($7.5 USD) per hour is the nominal minimum wage in South Korea,[127] although the real effective comparable minimum wage is higher at 10,474 won ($9.2 USD) per hour due to a mandatory weekly paid holiday for people that work more than 15 hours per week, a law that is absent in other developed countries.[128] The minimum wage law applies equally to foreign, temporary or young workers covering all industries and regions nationwide.
#
# 18,695
#
#
# 21,705
#
#
# 40
#
# 8.99
#
#
# 10.43
#
#
# 59.4%
#
# 1 January 2021
#
#
#
# 25
#
#  Kosovo
#
# €170 ($224) per month for workers between 35 and 65 years of age; €130 ($150) for workers under 35 years of age.[10][129]
#
# 2,330
#
#
# 6,220
#
#
# 40
#
# 1.12
#
#
# 2.99
#
#
# 61.8%
#
# 17 August 2011
#
#
#
# 25
#
#  Kuwait
#
# 60 Kuwaiti dinars ($216) per month.[10][130]
#
# 2,372
#
#
# 3,600
#
#
# 48
#
# 0.95
#
#
# 1.44
#
#
# 4.8%
#
# 14 April 2010
#
#
#
# 25
#
#  Kyrgyzstan
#
# 1140 Kyrgyzstani som ($14) per month, nominally; used for administrative purpose.[10][131][132][133]
#
# 196
#
#
# 661
#
#
# 40
#
# 0.09
#
#
# 0.32
#
#
# 18.6%
#
# 1 January 2017
#
#
#
# 25
#
#  Laos
#
# 800,000 Lao kip ($100) per month; additionally, employers were required to pay a 30,000-kip ($3.74) meal allowance per day. The minimum wage for civil servants and state enterprise employees was last increased to 1,400,000 kip ($170) per month.[10][134][135]
#
# 1,869
#
#
# 5,180
#
#
# 48
#
# 0.75
#
#
# 2.08
#
#
# 79.1%
#
# 2014
#
#
#
# 25
#
#  Latvia
#
# €500 ($571) per month.[136]
#
# 6,853
#
#
# 10,526
#
#
# 40
#
# 3.29
#
#
# 5.06
#
#
# 41.1%
#
# 1 January 2021
#
#
#
# 25
#
#  Lebanon
#
# 675,000 pounds ($446) per month ($66 using the parallel market rate as of 1-Jul-2020), or 30,000 pounds ($2.94) per day.[10][137]
#
# 5,212
#
#
# 8,947
#
#
# 48
#
# 2.09
#
#
# 3.58
#
#
# 62.5%
#
# 1 February 2012
#
#
#
# 25
#
#  Lesotho
#
# 1,178 maloti ($102) per month to 1,285 maloti ($112) per month; varied by sector.[10]
#
# 978
#
#
# 3,027
#
#
# 45
#
# 0.42
#
#
# 1.29
#
#
# 102.6%
#
# 2014
#
#
#
# 25
#
#  Liberia
#
# 15 Liberian dollars ($0.31) per hour not exceeding 8 hours per day, excluding benefits, for unskilled laborers; 5,600 LD ($114) per month for civil servants.[10]
#
# 774
#
#
# 10
#
#
# 48
#
# 0.31
#
#
# 0
#
#
# 1.2%
#
# 2014
#
#
#
# 25
#
#  Libya
#
# 450 Libyan dinars ($325) per month; the government heavily subsidizes rent and utilities.[10][138][139][140]
#
# 3,863
#
#
# 7,770
#
#
# 40
#
# 1.86
#
#
# 3.74
#
#
# 133.9%
#
# 1 March 2011
#
# 23
#
#  Liechtenstein
#
# None[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2014
#
#
#
# 21
#
#  Lithuania
#
# €607 ($693) per month, €3.72 ($4.25) per hour for unskilled labor.[141] Although, 141 article of the Labour code of Lithuania requires to pay more for the skilled labor.[142]
#
# 8,054
#
#
# 13,826
#
#
# 40
#
# 3.87
#
#
# 6.65
#
#
# 46.3%
#
# 1 January 2020
#
#
#
# 25
#
#  Luxembourg
#
# €2,071.10 ($2366) per month, €11.97 ($13.67) per hour for unskilled workers over 18; increased by 20% for a skilled employee; decreased by 20% to 25% in the case of an adolescent worker.[143][37][144][145]
#
# 28,438
#
#
# 24,651
#
#
# 40
#
# 13.67
#
#
# 11.85
#
#
# 24.1%
#
# 1 January 2019
#
#
#
# 25
#
#  North Macedonia
#
# 22,146 Macedonian denars (406$) gross per month.[94][146][147]
#
# 2,293
#
#
# 5,488
#
#
# 40
#
# 1.1
#
#
# 2.64
#
#
# 36.7%
#
# 1 April 2021
#
#
#
# 25
#
#  Macau
#
# 6656 Macanese patacas ($833) per month.[148]
#
# 9,897
#
#
# 13,584
#
#
# 40
#
# 4.76
#
#
# 6.53
#
#
# 11.7%
#
# 1 November 2020
#
#
#
# 25
#
#  Madagascar
#
# 133,013.40 Malagasy ariary per month, 767.40 ariary per hour for non-agricultural workers; 134,920.00 ariary per month, 674.60 ariary per hour for agricultural workers.[10][18]
#
# 397
#
#
# 1,601
#
#
# 41[149]
#
# 0.19
#
#
# 0.75
#
#
# 106.3%
#
# 1 January 2015
#
#
#
# 25
#
#  Malawi
#
# MK 687.70 per day.[10][18][150]
#
# 288
#
#
# 1,035
#
#
# 48
#
# 0.12
#
#
# 0.41
#
#
# 88.6%
#
# 1 January 2016
#
#
#
# 25
#
#  Malaysia
#
# RM1200 ($283) per month, or RM4.81 ($1.1) per hour on the peninsula; and RM920 ($224) per month, or RM4.42 ($1.0) per hour for the states of Sabah, Sarawak, and Labuan.[151][152] To be fully enforced on July 1, 2016.
#
# 2,663
#
#
# 6,646
#
#
# 48[10]
#
# 1.07
#
#
# 2.66
#
#
# 24%
#
# 1 January 2019
#
# 23
#
#  Maldives
#
# None; 3,100 Maldivian rufiyaa ($242) per month in the government sector.[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2014
#
#
#
# 21
#
#  Mali
#
# 28,465 CFA francs ($57), supplemented by a required package of benefits, including social security and health care.[10]
#
# 583
#
#
# 1,560
#
#
# 48[153]
#
# 0.23
#
#
# 0.62
#
#
# 73.4%
#
# 2014
#
#
#
# 25
#
#  Malta
#
# €778.34 ($889) per month, or €169.76 ($194) per week; combined with an annual mandatory bonus of €270.20 ($309) and a €242.32 ($277) annual cost of living increase, automatically adjusted for inflation.[154][155]
#
# 10,668
#
#
# 14,152
#
#
# 40
#
# 5.13
#
#
# 6.8
#
#
# 37.3%
#
# 1 January 2017
#
#
#
# 25
#
#  Marshall Islands
#
# US$2.00 per hour for government and private sector employees.[10][156]
#
# 4,160
#
#
# 3,902
#
#
# 40[157]
#
# 2
#
#
# 1.88
#
#
# 97%
#
# 6 March 1986
#
#
#
# 25
#
#  Mauritania
#
# 3,000 Mauritanian Ouguiya (30,000 Old Ouguiya, $83.8 in 2017 terms) per month for adults.[158][159]
#
# 981
#
#
# 295
#
#
# 40
#
# 0.47
#
#
# 0.14
#
#
# 7.7%
#
# 2011
#
#
#
# 25
#
#  Mauritius
#
# 2,035 Mauritian rupees (56.77 USD)  per week for an unskilled worker in the Export Processing Zone(EPZ); 2,035 rupee per week for an unskilled factory worker outside the EPZ plus a "salary compensation" of 90 rupees per week; set by the government by sector, and increased each year based on the inflation rate. Both categories of workers also benefit from a "special allowance" from the revenue agency which means that all full-time workers in Mauritius earn a minimum wage of 2,250 rupees (62.76 USD) per week or 9,000 rupees (251.05 USD) per month [160][161][10]
#
# 2,983
#
#
# 5,438
#
#
# 45
#
# 1.27
#
#
# 2.32
#
#
# 25.8%
#
# 2019
#
#
#
# 25
#
#  Mexico
#
# 172.87 Mexican pesos ($8.98) per day; 260.34 Mexican pesos ($13.51) per day on the Free Zone of the Northern Border. Day off is paid according to Mexican labor legislation so the total amount of paid hours is 56 (Art. 69) [162] but the working hours are 48.[18][163]
#
# 3,266
#
#
# 6,224
#
#
# 48
#
# 1.31
#
#
# 2.49
#
#
# 36%
#
# 2022
#
# 23
#
#  Moldova
#
# 2775 Moldovan lei ($156) per month in the private sector.[164]
#
# 1,895
#
#
# 4,854
#
#
# 40
#
# 0.91
#
#
# 2.33
#
#
# 91%
#
# 1 May 2019
#
# 23
#
#  Monaco
#
# €1,779.82 per month, or €10.53 per hour; same as the French minimum wage, plus a 5% adjustment.[165]
#
# 24,092
#
#
#
# 39
#
# 11.88
#
#
#
# 17%[166]
#
# 1 January 2019
#
#
#
# 21
#
#  Mongolia
#
# 420,000 Mongolian tögrög ($155) per month.[167]
#
# 1,892
#
#
# 6,068
#
#
# 40
#
# 0.91
#
#
# 2.92
#
#
# 49.5%
#
# 1 January 2020
#
#
#
# 25
#
#  Montenegro
#
# €193 ($215) per month.[10][168]
#
# 2,645
#
#
# 5,386
#
#
# 40
#
# 1.27
#
#
# 2.59
#
#
# 30.5%
#
# 1 May 2013
#
#
#
# 25
#
#  Morocco
#
# 3 000 MADs ($310) per month[169] in public sector, 2 570.86 MAD ($265) per month in private sector,[170] 69,73 MAD ($7) per day for agricultural workers.[171]
#
# 3,736
#
#
# 8,556
#
#
# 44[172]
#
# 1.63
#
#
# 3.74
#
#
# 108.9%
#
# 1 July 2015
#
#
#
# 25
#
#  Mozambique
#
# Set for nine different economic sectors; ranges from 3,002 Mozambican meticias ($51) per month in the public sector, to 7,465 meticias ($129) per month in the financial sector.[10][18]
#
# 576
#
#
# 1,818
#
#
# 40
#
# 0.28
#
#
# 0.87
#
#
# 149.4%
#
# 1 May 2014
#
#
#
# 25
#
#  Myanmar
#
# 3,600 Myanmar kyat per day, 450 Myanmar kyat per hour.[10][173][174]
#
# 672
#
#
# 3,011
#
#
# 44
#
# 0.29
#
#
# 1.32
#
#
# 52.6%
#
# 1 September 2015
#
# 23
#
#  Namibia
#
# None; the mining, construction, security and agricultural sectors set basic levels of pay through collective bargaining.[10]
#
#
#
#
#
# 45
#
#
#
#
#
#
#
# 2014
#
# 19
#
#  Nauru
#
# None; there is a graduated salary system for public service officers and employees, none for private-sector workers.[10]
#
#
#
#
#
# 40[175]
#
#
#
#
#
#
#
# 2014
#
#
#
# 21
#
#    Nepal
#
# 13,450 Nepalese rupees ($119) per month[176]
#
# 1,430
#
#
# 4,405
#
#
# 48
#
# 0.57
#
#
# 1.76
#
#
# 177.8%
#
# July 2018
#
#
#
# 25
#
#  Netherlands
#
# €1,701.00 ($1943) per month, €392.55 per week, €78.51 per day, and €9.82 ($11.22) per hour for persons 21 and older (in a 40-hours work week, €10.34 per hour in a 38-hours workweek and €10.91 per hour in a 36-hours workweek) ; between 30–80% (as low as €2.95 per hour[177]) of this amount for persons aged 15–20.[178]
#
# 23,315
#
#
# 22,935
#
#
# 40[179]
#
# 11.21
#
#
# 11.03
#
#
# 45.4%
#
# 1 July 2021
#
#
#
# 25
#
#  New Zealand
#
# NZ$20.00 per hour for workers 18 years old or older, and NZ$16.00 per hour for those aged 16 or 17 or in training; there is no statutory minimum wage for employees who are aged 15 years or under.[180][181]
#
# 27,407
#
#
# 25,366
#
#
# 40
#
# 13.18
#
#
# 12.2
#
#
# 65.8%
#
# 1 April 2021
#
#
#
# 25
#
#  Nicaragua
#
# Set for nine different economic sectors; ranges from 4,414 Nicaraguan córdobas per month in the agricultural sector to 7,133.44 córdobas per month in the financial sector.[18]
#
# 1,599
#
#
# 4,704
#
#
# 48
#
# 0.64
#
#
# 1.88
#
#
# 84.9%
#
# 1 March 2021
#
#
#
# 25
#
#  Niger
#
# 30,047 CFA francs ($60) per month.[10][18]
#
# 615
#
#
# 1,633
#
#
# 40
#
# 0.3
#
#
# 0.78
#
#
# 165.5%
#
# 17 August 2012
#
#
#
# 25
#
#  Nigeria
#
# 30,000 naira per month (following the recent devaluation of the naira has fallen to $76.92, or $66.6 using the parallel market rate).[182][183]
#
# 1,108
#
#
# 2,911
#
#
# 40
#
# 0.53
#
#
# 1.4
#
#
# 49.7%
#
# 18 November 2019
#
# 23
#
#  Northern Cyprus
#
# 2740 Turkish liras ($483) per month (gross minimum wage).[184]
#
# 9,012
#
#
#
# 40
#
#
#
#
#
#
#
# 1 March 2018
#
# 19
#
#  Norway
#
# None; wages normally fall within a national scale negotiated by labor, employers, and local governments.[10]
#
#
#
#
#
# 37.5
#
#
#
#
#
#
#
# 2014
#
#
#
# 21
#
#  Oman
#
# 225 Omani rials ($592) per month plus allowances of 100 rials ($263) per month for citizens; does not apply to foreign workers.[10][185]
#
# 10,143
#
#
# 19,500
#
#
# 45
#
# 4.33
#
#
# 8.33
#
#
# 42.5%
#
# 1 July 2013
#
#
#
# 25
#
#  Pakistan
#
# 17500 Pakistani rupees ($128) per month.[10][18][41]
#
# 1,539
#
#
# 6,546
#
#
# 48
#
# 0.62
#
#
# 2.62
#
#
# 125%
#
# 1 June 2016
#
#
#
# 25
#
#  Palau
#
# US$3.00 per hour; does not include foreign workers.[10][186]
#
# 6,240
#
#
# 6,638
#
#
# 40[187]
#
# 3
#
#
# 3.19
#
#
# 40.7%
#
# 1 October 2014
#
# 23
#
#  Palestine
#
# ₪1,450 ($407) per month;[188][189][190]
#
# 4,833
#
#
#
# 45
#
# 2.07
#
#
#
#
#
# 2014
#
# 19
#
#  Panama
#
# 1.53 to 4.45 balboas ($1.53 – $4.45 USD) per hour, depending on region and sector. Food and the use of housing facilities were considered part of the salary for some workers, such as domestic and agricultural workers. Salaries for domestic workers ranged from 250 to 275 balboas ($250-$275 USD) per month. The agricultural and construction sectors received the lowest and highest minimum wages, respectively.[10][191][192]
#
# 3,819
#
#
# 6,473
#
#
# 48
#
# 1.53
#
#
# 2.59
#
#
# 28.1%
#
# 1 January 2018
#
#
#
# 25
#
#  Papua New Guinea
#
# 3.20 Papua New Guinean kina ($1) per hour.[10][193]
#
# 2,161
#
#
# 2,795
#
#
# 44[194]
#
# 0.94
#
#
# 1.22
#
#
# 66.8%
#
# 1 August 2014
#
#
#
# 25
#
#  Paraguay
#
# 2,289,324 Paraguayan guaraníes ($335) per month; The law discriminates against domestic workers, who are legally entitled to only 40 percent of the minimum wage. The law mandates that housing and food be counted towards domestic worker's salary.[10][18][195][196]
#
# 4,402
#
#
# 10,575
#
#
# 48
#
# 1.76
#
#
# 4.24
#
#
# 110.5%
#
# 1 July 2021
#
#
#
# 25
#
#  Peru
#
# 930 Peruvian soles ($294) per month.[10][18]
#
# 3,344
#
#
# 6,414
#
#
# 48
#
# 1.34
#
#
# 2.57
#
#
# 49.3%
#
# 1 June 2018
#
#
#
# 25
#
#  Philippines
#
# Ranges from PhP243 ($4.60) daily non-agricultural wage in Ilocos to PhP537 ($10.16) daily non-agricultural wage in Metro Manila.[197]
#
# 2,696
#
#
# 6,912
#
#
# 40[198]
#
# 1.3
#
#
# 3.32
#
#
# 88.6%
#
# 16 March 2019
#
#
#
# 25
#
#  Poland
#
# 3,010 PLN ($784) per month, or 19.70 PLN ($5.13) per hour is the minimum wage in Poland.[199][18]
#
# 9,408
#
#
# 19,213
#
#
# 40
#
# 4.52
#
#
# 9.24
#
#
# 70.2%
#
# 1 January 2022
#
#
#
# 25
#
#  Portugal
#
# €741 per month ($800) in 12 payments; €635 per month ($685) in 14 payments for full-time workers, rural workers, and domestic employees ages 18 and older.[200][37]
#
# 9,594
#
#
# 12,353
#
#
# 40
#
# 4.61
#
#
# 5.94
#
#
# 40.3%
#
# 1 January 2020
#
# 23
#
#  Qatar
#
# 1000 Qatari riyals ($274) per month (in addition to the minimum wage, following applies; the provision of 500 riyals ($137) for accommodation and 300 riyals ($82.2) for food if those expenses are not provided as part of the contract).[201]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2020
#
#
#
# 21
#
#  Romania
#
# 2300 lei ($555.4) per month; else 14.044 lei ($3.29) per hour for a full-time schedule of 167 hours per month is the minimum wage in Romania.[202]
#
# 6,513
#
#
# 14,603
#
#
# 40
#
# 3.13
#
#
# 7.02
#
#
# 63.4%
#
# 1 January 2021
#
#
#
# 25
#
#  Russia
#
# 12792 RUB (173 USD)[203]
#
# 2,371
#
#
# 6,170
#
#
# 40
#
# 1.14
#
#
# 2.97
#
#
# 24.9%
#
# 1 January 2021
#
# 23
#
#  Rwanda
#
# None; ranges from 500 to 1,000 Rwandan francs ($0.83 to $1.66) per day in the tea industry and 1500 to 5000 francs ($2.50 to $8.30) per day in the construction industry.[10]
#
#
#
#
#
# 45
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  Saint Kitts and Nevis
#
# EC$9.00 per hour.[10][204][205]
#
# 6,933
#
#
# 9,087
#
#
# 40[206]
#
# 3.33
#
#
# 4.37
#
#
# 34.4%
#
# 1 November 2014
#
# 23
#
#  Saint Lucia
#
# Minimum wage for some sectors; EC$300 ($111) per month for office clerks; EC$200 ($74) for shop assistants; EC$160 ($59) for messengers.[10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  Saint Vincent and the Grenadines
#
# Set sector by sector; for example, EC$56 ($20.74) per day for agriculture workers (shelter not provided); EC$40 ($14.81) per day for industrial workers; and EC$25 per day for household domestic workers.[10][207][208]
#
# 2,407
#
#
# 3,351
#
#
# 40
#
# 1.16
#
#
# 1.61
#
#
# 29.2%
#
# 1 July 2008
#
#
#
# 25
#
#  Samoa
#
# WST$2.00 ($0.89) per hour for the private sector; WST$2.65 ($1.18) for the public sector.[10]
#
# 1,589
#
#
# 2,237
#
#
# 40
#
# 0.76
#
#
# 1.08
#
#
# 35.1%
#
# 2012
#
#
#
# 25
#
#  San Marino
#
# €1501.49 ($1735) per month; or €9.24 ($10) per hour for the lowest paying industry[209][10][210]
#
# 20,580
#
#
# 23,400
#
#
# 37.5[211]
#
# 10.55
#
#
# 12
#
#
# 38.4%
#
# 1 January 2017
#
# 23
#
#  São Tomé and Príncipe
#
# None; 750,000 São Tomé and Príncipe dobras ($40) per month for civil servants[80]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  Saudi Arabia
#
# 3,000 Saudi riyals ($800) per month for public sector; does not apply to foreign workers. There are no minimum wage in private sector.[10][212]
#
# 9,600
#
#
# 18,557
#
#
# 48
#
# 3.85
#
#
# 7.43
#
#
# 34.1%
#
# 2 February 2013
#
#
#
# 25
#
#  Senegal
#
# 209.10 CFA francs ($0.42) per hour for general workers and 182.95 CFA francs ($0.37) per hour for agricultural workers.[10][18][213]
#
# 649
#
#
# 1,617
#
#
# 40
#
# 0.31
#
#
# 0.78
#
#
# 63%
#
# 1 January 1996
#
#
#
# 25
#
#  Serbia
#
# 45,337 Serbian dinars ($436) gross monthly. Also, 201.22 Serbian dinars ($1.94) per hour net.[10][214]
#
# 3,410
#
#
# 7,291
#
#
# 40
#
# 1.64
#
#
# 3.51
#
#
# 50.2%
#
# 1 January 2022
#
#
#
# 25
#
#  Seychelles
#
# SR26.70 ($1.9) per hour for all workers other than casual workers; SR30.78 ($2.1) per hour for casual workers.[10][215][216]
#
# 3,957
#
#
# 6,435
#
#
# 40[217]
#
# 1.9
#
#
# 3.09
#
#
# 22.7%
#
# 1 January 2014
#
#
#
# 25
#
#  Sierra Leone
#
# 500,000 Sierra Leonean leones ($57) per month.[10][218][219][220]
#
# 666
#
#
# 2,602
#
#
# 40
#
# 0.32
#
#
# 1.25
#
#
# 176.2%
#
# 1 January 2015
#
# 23
#
#  Singapore
#
# None.[10] However, two exceptions: 1) Cleaner jobs to have a minimum wage of 1,200 Singapore dollars ($860) per month effective July 2019.[221] 2) Security guards to have a minimum wage of 1,100 SGD ($802) per month effective September 2016.[222]
#
#
#
#
#
# 44
#
#
#
#
#
#
#
# 2019
#
#
#
# 21
#
#  Slovakia
#
# €623 ($712) per month, or €3.58 ($4.09) per hour.[18][223]
#
# 8,410
#
#
# 13,388
#
#
# 40
#
# 4.04
#
#
# 6.44
#
#
# 44%
#
# 1 January 2021
#
#
#
# 25
#
#  Slovenia
#
# €886.63 per month.[18][37][224]
#
# 12,153
#
#
# 15,880
#
#
# 40
#
# 5.84
#
#
# 7.63
#
#
# 48.5%
#
# 1 January 2019
#
#
#
# 25
#
#  Solomon Islands
#
# SI$4.00 ($0.55) per hour for all workers except those in the fishing and agricultural sectors, who received SI$3.20 per hour.[10]
#
# 916
#
#
# 955
#
#
# 45
#
# 0.39
#
#
# 0.41
#
#
# 42.7%
#
# 1 May 2008
#
# 23
#
#  Somalia
#
# None.[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  South Africa
#
# R20 per hour for all workers, except for farm workers who have a minimum of R18, domestic workers who have a minimum of R15, and Expanded Public Works Programme workers who have a minimum of R11.[225]
#
# 3,239
#
#
# 8,897
#
#
# 45
#
# 1.38
#
#
# 3.8
#
#
# 67.4%
#
# 1 January 2019
#
# 23
#
#  South Sudan
#
# None.[226]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2011
#
#
#
# 21
#
#  Spain
#
# €1108 ($1266) per month in 12 payments, €950 ($1085) per month in 14 payments.[227]
#
# 15,187
#
#
# 17,968
#
#
# 40
#
# 7.3
#
#
# 8.64
#
#
# 49.5%
#
# 1 January 2020
#
#
#
# 25
#
#  Sri Lanka
#
# 10,000 rupees (US$70.75) per month.The minimum wages are set according to National Minimum Wage of Workers Act, No. 3 of 2016[18]
#
# 671
#
#
# 2,414
#
#
# 45
#
# 0.29
#
#
# 1.03
#
#
# 19.6%
#
# 1 January 2016
#
#
#
# 25
#
#  Sudan
#
# 425 Sudanese pounds (US$0.95 as of August 2021) per month.[228] See Minimum wage in Sudan.
#
# 84
#
#
# 1,087
#
#
# 40
#
# 0.04
#
#
# 0.52
#
#
# 23%
#
# 2013
#
# 23
#
#  Suriname
#
# None; SRD 600 ($180) per month is the lowest wage for civil servants.[10]
#
#
#
#
#
# 45
#
#
#
#
#
#
#
# 2013
#
# 19
#
#  Sweden
#
# None; in Sweden the law provides for the right of workers to form and join independent unions to bargain wages collectively, and it prohibits antiunion discrimination.[10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2017
#
# 19
#
#   Switzerland
#
# 20 Swiss francs ($20.13) per hour in the cantons Jura and Neuchâtel, the rest of the country has no minimum wage.[229] There are a minority of the voluntary General Labour Contracts (GLC, collective labour agreements), reached on a sector-by-sector basis,[230] contain minimum compensation clauses, which provide for compensation ranging from CHF 2,200 to 4,200 ($2214 to $4226) per month for unskilled workers and CHF 2,800 to 5,300 ($2818 to $5333) per month for skilled employees.[10] On 18 May 2014, Swiss voters rejected a federal initiative (by 76.3%) that would have enforced GLCs for every sector and set the hourly minimum wage at CHF 22 ($22.14, or PPP-adjusted $12.55).[231][232]
#
#
#
#
#
# 41.7[233][234]
#
#
#
#
#
#
#
# 2014
#
# 19
#
#  Syria
#
# 9,765 to 14,760 Syrian pounds ($6–$10)(adjusted for inflation) per month, plus benefits, including compensation for meals, uniforms, and transportation.[80]
#
# 96
#
# 2,850
#
# 40
#
# 0.4
#
# 1.37
#
# 54%
#
# 2013
#
# 19
#
#  Taiwan
#
# NT$24,000 ($854 USD) per month; NT$160 ($5.7USD) per hour is the minimum wage in Taiwan.[235][236]
#
# 9,702
#
# 22,359
#
# 40
#
# 5.26
#
# 12.12
#
# 39.1%
#
# 1 January 2021
#
# 19
#
#  Tajikistan
#
# 250 Tajikistani somoni ($31) per month, plus certain government subsidies for workers and their families.[80][237]
#
# 315
#
#
# 1,288
#
#
# 40
#
# 0.15
#
#
# 0.62
#
#
# 43.2%
#
# 1 September 2013
#
#
#
# 25
#
#  Tanzania
#
# Varies by sector from 40,000 Tanzanian shillings ($17) per month, to 400,000 shillings ($174) per month.[10][18]
#
# 209
#
#
# 593
#
#
# 45[238]
#
# 0.09
#
#
# 0.25
#
#
# 21.3%
#
# 1 July 2013
#
#
#
# 25
#
#  Thailand
#
# Ranges from 313 to 336 baht ($10.35–11.10) per day and up, depending on the cost of living in various provinces; set by provincial tripartite wage committees that sometimes include only employer representatives.[239]
#
# 3,316
#
#
# 8,031
#
#
# 48
#
# 1.33
#
#
# 3.22
#
#
# 47.5%
#
# 1 January 2020
#
#
#
# 25
#
#  Timor-Leste
#
# US$115 per month.[10][240]
#
# 1,380
#
#
# 2,123
#
#
# 44
#
# 0.6
#
#
# 0.93
#
#
# 99.2%
#
# 22 June 2012
#
#
#
# 25
#
#  Togo
#
# 35,000 ($70) CFA francs per month.[10][18]
#
# 717
#
#
# 1,796
#
#
# 40
#
# 0.34
#
#
# 0.86
#
#
# 120.5%
#
# 1 January 2012
#
# 23
#
#  Tonga
#
# None[10]
#
#
#
#
#
# 40
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  Trinidad and Tobago
#
# TT$15.00 ($2.36) per hour.,[241] ($355) per month
#
# 4,619
#
#
# 5,503
#
#
# 40
#
# 2.22
#
#
# 2.65
#
#
# 16.7%
#
# 1 January 2015
#
#
#
# 25
#
#  Tunisia
#
# For the industrial sector: 465 Tunisian dinars ($166) per month for a 48-hour workweek and 401 dinars ($143) per month for a 40‑hour workweek.[242]
#
# 1,902
#
#
# 6,723
#
#
# 48
#
# 0.76
#
#
# 2.69
#
#
# 58%
#
# 2020
#
#
#
# 25
#
#  Turkey
#
# 3,446 Turkish liras ($255) per month.[243]
#
# 7,288
#
#
# 25,845
#
#
# 45
#
# 3.11
#
#
# 11.04
#
#
# 102.4%
#
# 1 January 2022
#
#
#
# 25
#
#  Turkmenistan
#
# 535 Turkmenistani manat ($156) per month.[10][244]
#
# 1,834
#
#
# 4,842
#
#
# 40
#
# 0.88
#
#
# 2.33
#
#
# 28.7%
#
# 1 January 2015
#
# 23
#
#  Tuvalu
#
# None; the minimum annual salary in the public sector was approximately A$3,000 to A$4,000 ($3,120 to $4,160).[10]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  Uganda
#
# 130,000 Ugandan shillings ($34.58) per month.[10][18][41]
#
# 417
#
#
# 1,298
#
#
# 40
#
# 0.2
#
#
# 0.62
#
#
# 71.3%
#
# 1 July 2017
#
#
#
# 25
#
#  Ukraine
#
# ₴ 6500 (UAH) ($239.23) per month, 39,12 hryvnias ($1.44) per hour, annual wage 2,870 US.[18][245]
#
# 3,018
#
#
# 13,198
#
#
# 40
#
# 1.45
#
#
# 6.35
#
#
# 159.6%
#
# 1 December 2021
#
# 23
#
#  United Arab Emirates
#
# None.[10]
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  United Kingdom
#
# The minimum wage in the United Kingdom is:  £8.91 ($11.37) per hour for those aged 23+  £8.36 ($10.67) per hour for those aged 21–22 £6.56 ($8.37) per hour for those aged 18–20 £4.62 ($5.9) per hour for under 18 £4.30 ($5.49) per hour for apprentices aged 16 to 18 and those aged 19 or over who are in their first year[246]
#
# 23,656
#
#
# 23,166
#
#
# 40
#
# 11.37
#
#
# 11.14
#
#
# 54.3%
#
# 1 April 2021
#
#
#
# 25
#
#  United States
#
# The federal nationwide minimum wage in the United States is US$7.25 per hour.[247] States may also set a minimum, in which case the higher of the two is controlling; some territories are exempt and have lower rates.[247] As of July 1, 2019[update], effective state minimum wage rates range from $7.25 to $14.00 per hour.[248][249] Local government minimum wages exist as well, the highest of which reach to $16 per hour.[250]
#
# 15,080
#
#
# 15,080
#
#
# 40
#
# 7.25
#
#
# 7.25
#
#
# 26.2%
#
# 24 July 2009
#
#
#
# 25
#
#  Uruguay
#
# 17,930 Uruguayan pesos ($423) per month.[251][252]
#
# 6,103
#
#
# 9,183
#
#
# 48
#
# 2.45
#
#
# 3.68
#
#
# 42.5%
#
# 2021
#
#
#
# 25
#
#  Uzbekistan
#
# 634,880 Uzbekistani som ($66) per month.[10][253]
#
# 862
#
#
# 7,954
#
#
# 40
#
# 0.41
#
#
# 3.82
#
#
# 122.1%
#
# 1 September 2019
#
#
#
# 25
#
#  Vanuatu
#
# 30,000 Vanuatu vatu ($323) per month, 170 vatu per hour.[10][254]
#
# 3,095
#
#
# 3,041
#
#
# 40
#
# 1.49
#
#
# 1.46
#
#
# 98.7%
#
# 20 August 2012
#
# 23
#
#  Venezuela
#
# The minimum wage in Venezuela is 400,000 Venezuelan Bolívares per month, including a food bond the total raises up to 800,000 Bolívares, which is equivalent to about US$0.86 as November 26.[255][256][257]
#
# 10.32
#
#
#
#
#
#
#
#
#
#
#
# 1 May 2020
#
# 19
#
#  Vietnam
#
# Varies by region; Region I: VND 3,980,000 per month; Region II: VND 3,530,000 per month; Region III: VND 3,090,000 per month and Region IV: VND 2,760,000 per month.[10][18]
#
# 1,437
#
#
# 3,676
#
#
# 40
#
# 0.69
#
#
# 1.77
#
#
# 58.4%
#
# 1 January 2018
#
# 23
#
#  Yemen
#
# None; the minimum civil service wage was 21,000 rials ($100) per month.
#
#
#
#
#
# 48
#
#
#
#
#
#
#
# 2013
#
#
#
# 21
#
#  Zambia
#
# Varies by sector; K993.60 Zambian kwacha ($81) per month for domestic workers. Shop workers’ minimum wage is K1,698.60 with transport, lunch and housing allowances inclusive, and wages increasing according to the grades of employees, with the minimum wage of the highest grade in this category being K3,558.90. In the general workers’ category, which includes receptionists and guards among others, the minimum wage for category one workers is K1,698.60, while the highest category is at K3,151.61.[258]
#
# 925
#
#
# 3,180
#
#
# 48
#
# 0.37
#
#
# 1.27
#
#
# 80.8%
#
# 10 September 2018
#
# 23
#
#  Zimbabwe
#
# None, except for agricultural and domestic workers; government regulations for each of the 22 industrial sectors specify minimum wages. The minimum wage for all mine workers is currently pegged at $227 per month.[126]
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2012
#
# 19

# %%
# 1, 3, 5, 8
min_wage_text_wiki_df = pd.DataFrame(min_wage_countries_list)
min_wage_text_wiki_df[1:5]
# Out:
#   0         1  2                                                  3  4   \
# 1      Albania     30,000 Albanian lekë ($280) per month, in priv...
# 2      Algeria     20,000 Algerian dinars ($156.19) per month, na...
# 3      Andorra               €1050.40 per month, €6.06 per hour.[16]
# 4       Angola     21,454 kwanza ($58) per month; paid thirteen t...
#
#        5  6       7      8   9   ...              17 18     19 20  \
# 1   3,277             6,523      ...                     56.5%
# 2   2,010             6,247      ...                     41.6%
# 3  14,397     11,020         40  ...  1 January 2019
# 4     764             2,108      ...                     32.7%
#
#              21    22    23    24    25    26
# 1    5 May 2017                    None  None
# 2    1 May 2020        None  None  None  None
# 3          None  None  None  None  None  None
# 4  1 April 2019                    None  None
#
# [4 rows x 27 columns]

# %%
country_names_list = []

for country in country_names:
    # print(country.get_text())
    if country.get_text():
        print(country.get_text())
# Out:
# Australia
# Belgium
# Canada
# Chile
# Colombia
# Costa Rica
# Czech Republic
# Estonia
# France
# Germany
# Greece
# Hungary
# Ireland
# Israel
# Japan
# Korea
# Latvia
# Lithuania
# Luxembourg
# Mexico
# Netherlands
# New Zealand
# Poland
# Portugal
# Slovak Republic
# Slovenia
# Spain
# Turkey
# United Kingdom
# United States
# Brazil
# Russian Federation

# %%
min_wage_text_df = pd.DataFrame(min_wage_data_text)
min_wage_text_df
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\pandas\core\internals\construction.py:309: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
#                       0   1           2           3           4           5   \
# 0            [Australia]  []  [21 685.5]  [21 899.2]  [22 184.9]  [22 574.3]
# 1              [Belgium]  []  [22 912.0]  [23 219.2]  [23 084.9]  [22 834.8]
# 2               [Canada]  []  [15 126.8]  [14 967.8]  [14 757.6]  [14 781.2]
# 3                [Chile]  []   [4 510.4]   [4 640.3]   [4 704.2]   [4 835.7]
# 4             [Colombia]  []   [6 241.6]   [6 340.8]   [6 359.3]   [6 475.2]
# 5           [Costa Rica]  []   [7 825.7]   [7 728.0]   [7 785.1]   [7 695.8]
# 6       [Czech Republic]  []   [6 343.3]   [7 096.3]   [7 709.6]   [8 107.6]
# 7              [Estonia]  []   [3 422.3]   [3 820.6]   [4 402.0]   [4 904.6]
# 8               [France]  []  [18 450.6]  [18 683.7]  [19 004.5]  [19 641.0]
# 9              [Germany]  []        [..]        [..]        [..]        [..]
# 10              [Greece]  []  [13 680.9]  [13 905.1]  [14 118.9]  [14 424.1]
# 11             [Hungary]  []   [6 168.1]   [7 324.4]   [6 998.2]   [6 949.4]
# 12             [Ireland]  []  [15 955.8]  [16 017.2]  [16 190.9]  [17 339.3]
# 13              [Israel]  []  [12 106.7]  [11 718.2]  [11 878.1]  [11 927.2]
# 14               [Japan]  []  [12 787.9]  [13 000.7]  [13 098.3]  [13 119.2]
# 15               [Korea]  []   [8 266.2]   [8 933.9]   [9 410.3]  [10 113.5]
# 16              [Latvia]  []   [2 310.8]   [2 469.7]   [2 823.4]   [3 156.5]
# 17           [Lithuania]  []   [4 684.7]   [4 671.6]   [4 798.5]   [5 250.1]
# 18          [Luxembourg]  []  [22 743.6]  [22 698.4]  [23 547.7]  [23 513.5]
# 19              [Mexico]  []   [1 995.8]   [2 010.0]   [2 009.1]   [2 000.8]
# 20         [Netherlands]  []  [24 518.6]  [24 787.8]  [25 036.0]  [24 876.9]
# 21         [New Zealand]  []  [14 897.7]  [15 007.4]  [15 582.3]  [16 121.6]
# 22              [Poland]  []   [7 139.8]   [7 006.3]   [7 325.0]   [7 297.9]
# 23            [Portugal]  []   [9 857.5]   [9 908.3]   [9 836.2]   [9 838.1]
# 24     [Slovak Republic]  []   [5 111.6]   [5 561.2]   [5 742.8]   [5 796.6]
# 25            [Slovenia]  []  [10 527.0]  [10 920.6]  [11 279.4]  [11 649.4]
# 26               [Spain]  []  [12 117.4]  [11 994.4]  [11 877.5]  [11 764.8]
# 27              [Turkey]  []   [6 924.9]   [7 421.0]   [7 898.2]  [10 305.0]
# 28      [United Kingdom]  []  [14 877.7]  [15 915.5]  [16 279.2]  [17 222.2]
# 29       [United States]  []  [15 657.3]  [15 412.8]  [15 070.7]  [14 677.8]
# 30              [Brazil]  []   [2 646.7]   [2 754.8]   [2 832.5]   [2 926.7]
# 31  [Russian Federation]  []     [557.1]     [769.8]     [825.4]     [916.1]
#
#             6           7           8           9   ...          12  \
# 0   [22 757.3]  [22 409.0]  [23 152.2]  [22 746.7]  ...  [23 097.0]
# 1   [22 660.5]  [22 703.3]  [22 965.4]  [22 872.7]  ...  [23 375.3]
# 2   [14 911.1]  [15 240.1]  [15 392.2]  [16 013.9]  ...  [17 616.7]
# 3    [4 928.5]   [5 055.7]   [5 146.6]   [5 141.2]  ...   [5 711.3]
# 4    [6 568.5]   [6 735.6]   [6 783.7]   [6 746.4]  ...   [7 104.3]
# 5    [7 753.5]   [7 837.5]   [7 906.5]   [8 066.0]  ...   [8 561.7]
# 6    [8 535.9]   [8 994.1]   [9 012.2]   [8 473.4]  ...   [8 110.6]
# 7    [5 111.3]   [5 458.1]   [6 144.2]   [6 727.3]  ...   [6 228.0]
# 8   [20 399.7]  [20 910.2]  [21 122.0]  [21 162.9]  ...  [21 364.5]
# 9         [..]        [..]        [..]        [..]  ...        [..]
# 10  [14 704.2]  [15 129.1]  [15 492.8]  [15 797.8]  ...  [15 646.7]
# 11   [7 216.9]   [7 614.0]   [7 391.2]   [7 342.5]  ...   [7 308.7]
# 12  [18 097.2]  [17 928.1]  [18 945.5]  [18 571.3]  ...  [19 133.5]
# 13  [11 772.7]  [12 109.3]  [12 665.6]  [12 446.9]  ...  [11 946.2]
# 14  [13 186.1]  [13 222.4]  [13 357.7]  [13 458.2]  ...  [14 591.2]
# 15  [10 994.5]  [11 390.3]  [12 470.4]  [12 906.4]  ...  [13 440.5]
# 16   [3 079.9]   [3 374.9]   [4 398.2]   [5 671.3]  ...   [6 678.3]
# 17   [5 555.1]   [5 864.8]   [6 270.1]   [6 956.9]  ...   [6 312.9]
# 18  [23 986.2]  [23 848.0]  [24 295.0]  [23 985.1]  ...  [24 774.0]
# 19   [2 010.5]   [2 017.6]   [2 016.1]   [1 994.7]  ...   [2 008.6]
# 20  [24 463.9]  [24 460.1]  [24 644.0]  [24 723.7]  ...  [24 904.7]
# 21  [16 555.8]  [17 183.6]  [18 325.8]  [18 930.0]  ...  [19 078.0]
# 22   [7 358.6]   [7 693.1]   [7 817.6]   [9 028.4]  ...  [10 012.9]
# 23   [9 872.0]   [9 855.4]  [10 051.0]  [10 356.4]  ...  [11 312.4]
# 24   [6 022.4]   [6 178.9]   [6 565.5]   [6 581.6]  ...   [7 278.7]
# 25  [11 932.7]  [12 035.6]  [11 901.8]  [12 171.4]  ...  [15 203.3]
# 26  [12 404.6]  [12 914.5]  [13 254.2]  [13 391.3]  ...  [13 666.1]
# 27  [10 737.0]  [10 644.7]  [10 575.7]  [10 406.7]  ...  [11 098.6]
# 28  [18 024.7]  [18 389.1]  [18 907.0]  [18 881.8]  ...  [18 620.6]
# 29  [14 196.1]  [13 752.5]  [14 167.4]  [15 393.9]  ...  [17 350.8]
# 30   [3 099.0]   [3 502.0]   [3 729.3]   [3 876.3]  ...   [4 388.0]
# 31   [1 002.7]   [1 359.0]   [2 606.8]   [2 284.5]  ...   [3 450.4]
#
#             13          14          15          16          17          18  \
# 0   [23 411.6]  [23 481.0]  [23 554.3]  [23 841.6]  [24 118.0]  [24 333.1]
# 1   [23 184.5]  [23 618.7]  [23 538.7]  [23 407.2]  [23 184.3]  [23 156.4]
# 2   [17 947.1]  [18 065.3]  [18 181.9]  [18 463.6]  [18 749.0]  [19 075.0]
# 3    [5 873.5]   [6 157.5]   [6 355.1]   [6 526.8]   [6 885.7]   [7 090.5]
# 4    [7 286.1]   [7 429.3]   [7 544.6]   [7 516.7]   [7 480.8]   [7 673.5]
# 5    [8 706.7]   [8 781.7]   [8 744.2]   [9 265.8]   [9 527.4]   [9 374.9]
# 6    [7 852.5]   [7 942.7]   [8 196.8]   [8 844.4]   [9 452.8]  [10 251.8]
# 7    [6 250.5]   [6 710.5]   [7 452.4]   [8 227.6]   [9 058.0]   [9 573.5]
# 8   [21 638.7]  [21 729.9]  [21 849.3]  [22 024.6]  [22 121.5]  [22 099.3]
# 9         [..]        [..]        [..]  [23 501.2]  [23 386.2]  [23 966.4]
# 10  [12 910.8]  [12 601.9]  [12 769.4]  [12 994.9]  [13 103.1]  [12 957.8]
# 11   [8 248.0]   [8 543.4]   [8 868.7]   [9 180.2]   [9 666.6]  [10 861.5]
# 12  [18 814.4]  [18 719.2]  [18 685.1]  [18 739.4]  [19 820.9]  [19 969.6]
# 13  [12 233.8]  [12 479.3]  [12 418.9]  [13 261.1]  [13 845.4]  [14 576.8]
# 14  [14 763.3]  [14 965.9]  [14 858.7]  [15 059.0]  [15 456.2]  [15 862.5]
# 15  [12 895.5]  [13 508.1]  [14 298.6]  [15 206.7]  [16 274.9]  [17 129.4]
# 16   [6 505.1]   [6 394.2]   [7 159.8]   [8 016.7]   [8 215.5]   [8 293.9]
# 17   [6 283.1]   [7 575.2]   [7 635.2]   [8 238.0]   [9 535.7]   [9 571.2]
# 18  [24 583.8]  [24 558.3]  [25 613.8]  [25 668.4]  [25 594.0]  [26 148.0]
# 19   [2 011.8]   [2 020.6]   [2 018.2]   [2 059.2]   [2 128.2]   [2 199.3]
# 20  [24 813.0]  [24 507.3]  [24 617.1]  [24 657.7]  [25 055.9]  [25 159.2]
# 21  [19 516.3]  [19 748.3]  [20 132.4]  [20 784.2]  [21 356.7]  [21 661.8]
# 22  [10 464.0]  [11 051.9]  [11 598.3]  [12 188.1]  [12 970.8]  [13 737.3]
# 23  [11 007.1]  [10 977.0]  [11 007.6]  [11 406.0]  [11 898.2]  [12 335.6]
# 24   [7 251.5]   [7 380.8]   [7 699.2]   [8 338.8]   [8 933.8]   [9 471.3]
# 25  [15 161.2]  [15 300.4]  [15 368.1]  [15 489.2]  [15 497.7]  [15 554.3]
# 26  [13 339.8]  [13 234.5]  [13 254.5]  [13 389.3]  [13 550.5]  [14 358.1]
# 27  [11 399.7]  [11 609.9]  [11 758.1]  [12 614.2]  [15 136.8]  [14 698.2]
# 28  [18 582.2]  [18 500.5]  [18 643.7]  [19 130.8]  [20 821.1]  [20 932.9]
# 29  [16 999.0]  [16 753.6]  [16 486.2]  [16 466.6]  [16 261.5]  [15 922.3]
# 30   [4 758.5]   [4 883.9]   [4 904.9]   [4 896.3]   [5 028.5]   [5 175.9]
# 31   [3 369.3]   [3 562.8]   [3 525.8]   [3 277.0]   [3 184.6]   [3 787.4]
#
#             19          20          21
# 0   [24 688.5]  [25 085.5]  [25 464.6]
# 1   [22 915.3]  [23 042.1]  [23 139.6]
# 2   [21 079.8]  [21 433.1]  [21 823.7]
# 3    [7 258.9]   [7 554.0]   [7 782.5]
# 4    [7 871.2]   [8 059.4]   [8 332.6]
# 5    [9 394.1]   [9 447.6]   [9 616.4]
# 6   [11 131.0]  [11 976.0]  [12 554.9]
# 7    [9 846.2]  [10 397.1]  [11 294.5]
# 8   [21 964.5]  [22 053.5]  [22 211.6]
# 9   [23 558.3]  [24 137.3]  [24 435.1]
# 10  [12 877.3]  [14 128.9]  [14 425.7]
# 11  [11 416.8]  [11 928.6]  [12 474.3]
# 12  [20 517.0]  [20 858.3]  [21 526.2]
# 13  [15 326.2]  [15 197.9]  [15 287.8]
# 14  [16 186.9]  [16 604.9]  [16 989.5]
# 15  [19 645.8]  [21 702.1]  [22 206.5]
# 16   [9 244.0]   [9 085.6]   [9 011.7]
# 17   [9 810.3]  [13 301.2]  [14 375.0]
# 18  [26 022.6]  [26 467.7]  [26 908.7]
# 19   [2 314.5]   [2 595.6]   [3 012.1]
# 20  [25 176.3]  [25 142.4]  [25 454.5]
# 21  [22 088.6]  [22 861.2]  [24 555.1]
# 22  [14 167.3]  [14 848.5]  [16 598.1]
# 23  [12 718.7]  [13 112.8]  [13 879.5]
# 24  [10 194.8]  [10 757.7]  [11 771.0]
# 25  [16 007.0]  [16 569.5]  [17 587.3]
# 26  [14 684.3]  [17 834.0]  [18 885.7]
# 27  [14 425.9]  [12 466.4]  [12 777.8]
# 28  [21 347.8]  [21 986.5]  [23 044.9]
# 29  [15 542.7]  [15 266.0]  [15 080.0]
# 30   [5 083.5]   [5 126.5]   [5 198.4]
# 31   [5 103.4]   [5 196.0]   [5 404.8]
#
# [32 rows x 22 columns]
